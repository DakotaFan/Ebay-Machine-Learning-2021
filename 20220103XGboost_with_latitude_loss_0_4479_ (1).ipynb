# %%
import pandas as pd
import numpy as np
from numpy import random
random.seed(1998)
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ebay
#%cd /content/drive/MyDrive/tempShare
df = pd.read_csv('eBay_ML_Challenge_Dataset_2021_train.tsv', sep='\t')
quiz = pd.read_csv('eBay_ML_Challenge_Dataset_2021_quiz.tsv', sep='\t')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ebay

# %%
pip install pgeocode
# Out:
# Collecting pgeocode
#   Downloading pgeocode-0.3.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pgeocode) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pgeocode) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pgeocode) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pgeocode) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pgeocode) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pgeocode) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (3.0.4)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.3.0

# %%
import pgeocode
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
df
# Out:
#          b2c_c2c  seller_id  ...            package_size record_number
# 0            B2C      25454  ...                  LETTER             1
# 1            C2C    6727381  ...  PACKAGE_THICK_ENVELOPE             2
# 2            B2C      18507  ...  PACKAGE_THICK_ENVELOPE             3
# 3            B2C       4677  ...  PACKAGE_THICK_ENVELOPE             4
# 4            B2C       4677  ...  PACKAGE_THICK_ENVELOPE             5
# ...          ...        ...  ...                     ...           ...
# 14999995     B2C      80139  ...  PACKAGE_THICK_ENVELOPE      14999996
# 14999996     C2C     452486  ...  PACKAGE_THICK_ENVELOPE      14999997
# 14999997     B2C      43307  ...                    NONE      14999998
# 14999998     B2C      24235  ...  PACKAGE_THICK_ENVELOPE      14999999
# 14999999     C2C     535916  ...  PACKAGE_THICK_ENVELOPE      15000000
#
# [15000000 rows x 19 columns]

# %% [markdown]
# #Preprocessing Data and feature engineering

# %%
dist = pgeocode.GeoDistance('US')
postal = pgeocode.Nominatim('US')

def calculate_distance(subset):
  x = subset['buyer_zip_new']
  y = subset['item_zip_new']
  distance = dist.query_postal_code(x.to_numpy(), y.to_numpy())
  subset['distance'] = pd.DataFrame({'col': distance})
  return subset

def return_state(subset):
  x = subset['buyer_zip_new']
  y = subset['item_zip_new']
  buyer_states = postal.query_postal_code(x.to_numpy())['state_code']
  item_states = postal.query_postal_code(y.to_numpy())['state_code']
  #the adding latitude is here, in case you need to delete it in the future
  item_lat = postal.query_postal_code(y.to_numpy())['latitude']
  item_long = postal.query_postal_code(y.to_numpy())['longitude']
  buyer_lat = postal.query_postal_code(x.to_numpy())['latitude']
  buyer_long = postal.query_postal_code(x.to_numpy())['longitude']

  return buyer_states.tolist(), item_states.tolist(), item_lat.tolist(), item_long.tolist(), buyer_lat.tolist(), buyer_long.tolist() 


  
def calculating_duration(df):
  df['delivery_date2'] = df['delivery_date'].apply(lambda x: x[:10])
  #convert to datetime for further calculation
  df['delivery_date2'] = pd.to_datetime(df['delivery_date2'])
  #first have to check if there is incorrect data in the delivery time and payment time
  df['duration'] = df['delivery_date2'] - df['acceptance_scan_time2']
  df['duration'] = df.loc[:, 'duration'].dt.days
  return df

def assign_state_code(df):
  buyer, item,item_lat, item_long, buyer_lat, buyer_long = return_state(df)
  df['buyer_state'] = pd.DataFrame({'col': buyer})
  df['item_state'] = pd.DataFrame({'col': item})
  '''here you add the lattitude and longtitude code'''
  df['item_lat'] = pd.DataFrame({'col': item_lat})
  df['item_long'] = pd.DataFrame({'col': item_long})
  df['buyer_lat'] = pd.DataFrame({'col': buyer_lat})
  df['buyer_long'] = pd.DataFrame({'col': buyer_long})
  return df

# 25% quantile 
def q25(x):
    return x.quantile(0.25)
# 75th Percentile
def q75(x):
    return x.quantile(0.75)

# %%
def preprocessing_data(df):
  #calculate the time zone difference between seller and buyer
  df['time_zone_difference'] = df['acceptance_scan_timestamp'].apply(lambda x: x[-6:-3]).astype(int) - df['payment_datetime'].apply(lambda x: x[-6:-3]).astype(int) 
  #calculate the seller hours when the payment is being made
  df['seller_hour'] = df['payment_datetime'].apply(lambda x: x[11:13]).astype(int) + df['time_zone_difference'] 
  #check if the seller hour is after 2 pm
  lst_2pm = df['seller_hour'] >= 14
  df['larger_than_2pm'] = pd.DataFrame({'col': lst_2pm})
  #data cleaning for the time data
  df['acceptance_scan_time2'] = df['acceptance_scan_timestamp'].apply(lambda x: x[:10])
  df['payment_date2'] = df['payment_datetime'].apply(lambda x: x[:10])
  #convert to datetime for further calculation
  df['payment_date2'] = pd.to_datetime(df['payment_date2'])
  df['acceptance_scan_time2'] = pd.to_datetime(df['acceptance_scan_time2'])
  # extract day of month, year, 
  df['pay_month'] = df.payment_date2.dt.month
  df['pay_year'] = df.payment_date2.dt.year
  df['scan_month'] = df.acceptance_scan_time2.dt.month

  #extract daytime of the payment time, and acceptance time
  df['payment_hour'] = df['payment_datetime'].apply(lambda x: x[11:13]).astype(int)
  df['scan_hour'] = df['acceptance_scan_timestamp'].apply(lambda x: x[11:13]).astype(int)

  #extract the day of the week of payment time and acceptance time
  df['Weekday_scan'] = df['acceptance_scan_time2'].dt.weekday
  df['Weekday_pay'] = df['payment_date2'].dt.weekday


  #extract quarter of the payment
  df['payment_quarter'] = df['payment_date2'].dt.quarter
  df['min_delivery'] = df['carrier_min_estimate'] + df['declared_handling_days'] #new feature
  df['max_delivery'] = df['carrier_max_estimate'] + df['declared_handling_days'] #new feature

  #convert the zip code to string 
  df['buyer_zip_new'] = df['buyer_zip'].astype(str).apply(lambda x: x[:5])
  df['item_zip_new'] = df['item_zip'].astype(str).apply(lambda x: x[:5])
  
  #convert the categorical data to boolean type of data
  df['b2c_c2c'] = df['b2c_c2c'].astype(str)
  lst_b2b = df.iloc[:, 0] == 'B2C'
  df['B2B'] = pd.DataFrame({'col': lst_b2b})

  #return the state_code of each item and customer

  '''here you also add the lattitude and longtitude'''

  assign_state_code(df)


  #calculate the distance between item and buyer
  df = calculate_distance(df)

  #assign state code to each item and customer
  df = assign_state_code(df)
  
  #check if there is miss-matching date for delivery and payment
  package_dic = {'NONE': 0, 'LETTER': 1, 'PACKAGE_THICK_ENVELOPE': 2, 'LARGE_ENVELOPE': 3, 'LARGE_PACKAGE': 4, 'EXTRA_LARGE_PACKAGE': 5,  'VERY_LARGE_PACKAGE': 6}
  df.loc[:, 'size_ordinal'] = df.package_size.map(package_dic)

  return df

# %%
def adding_features(df):
  #check if the customer is making a purchase during weekends, if the carrier is scanning/working on weekends
  #since the Friday = 4, Saturday = 5, and Sunday = 6
  df['is_payment_weekend'] = df['Weekday_pay'] > 4
  df['is_scan_weeknd'] = df['Weekday_scan'] > 4

  return df

# %%
df = preprocessing_data(df)
quiz = preprocessing_data(quiz)
df = adding_features(df)
quiz = adding_features(quiz)

#adding our target variable to the dataframe, which is the duration between the carrier scanning time and the delivery date
df = calculating_duration(df)

# %%
#we can find that the there is a lot of missing distance(179057 data)
#this is partially because there are international customers and sellers
#we are gonna use a different method to get their distance

missing_dist = df[df['distance'].isnull()]

# %%
US_state = df['buyer_state'].unique()
US_state
# Out:
# array(['MI', 'IL', 'WI', 'CO', 'MN', 'TX', 'SC', 'FL', 'UT', 'MD', 'NC',
#        'OH', 'MO', 'CA', 'PA', 'ID', 'NY', 'KS', 'GA', 'ME', 'KY', 'VA',
#        'MA', 'AZ', 'AL', 'NJ', 'MT', 'CT', 'WY', 'OK', 'LA', 'IN', 'TN',
#        'NE', 'WA', 'NM', 'MS', 'AR', 'OR', 'IA', 'WV', 'VT', 'NV', nan,
#        'ND', 'SD', 'DC', 'NH', 'DE', 'RI', 'AK', 'HI'], dtype=object)

# %%
#sometimes the US states will have the same abbreviation as other countries' country code
for i in range(52):
  if US_state[i] in missing_state:
    print("collision detect")
    print(US_state[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-12771560a4c8> in <module>()
#       1 #sometimes the US states will have the same abbreviation as other countries' country code
#       2 for i in range(52):
# ----> 3   if US_state[i] in missing_state:
#       4     print("collision detect")
#       5     print(US_state[i])
#
# NameError: name 'missing_state' is not defined

# %%
missing_dist = missing_dist[['record_number', 'item_zip', 'buyer_zip'
# Out:
#   File "<ipython-input-12-ba60da65202a>", line 1
#     missing_dist = missing_dist[['record_number', 'item_zip', 'buyer_zip'
#                                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
df['Is_within_US'] = df['distance'].notnull()

# %%
quiz['Is_within_US'] = quiz['distance'].notnull()

# %%
#df['missing_distance_max'] =  pd.DataFrame({'col': np.zeros((len(df)))})
#df['missing_distance_mean'] = pd.DataFrame({'col': np.zeros((len(df)))})
#df.loc[df['distance'].isnull(), 'missing_distance_mean'] =  missing_dist['duration'].mean()
#df.loc[df['distance'].isnull(), 'missing_distance_max'] = missing_dist['duration'].max()

# %%
missing = pd.read_csv('missing.csv')

# %%
missing = missing[['missing_zip', 'state_name', 'latitude', 'longtitude']]

# %%
missing['state_name'] = missing.state_name.replace({'CO': 'Columbia', 'CA' : 'Canada', 'IN': 'India', 'AR':'Argentina', 'DE': 'Germany' })

# %%
for i in range(52):
  if US_state[i] in missing['state_name'].unique():
    print("collision detect")
    print(US_state[i])
  else:
    print('NO Collision detected')
# Out:
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected
# NO Collision detected

# %%
def find_missing_location(dataframe):
  if dataframe['buyer_state'] is None:
    buyer_lattitude = missing
# Out:
#      missing_zip state_name  latitude  longtitude
# 0          00627         PR   18.4838    -66.8449
# 1         518000        NaN       NaN         NaN
# 2         510420        NaN       NaN         NaN
# 3         610000         RU   58.5969     49.6583
# 4         510655        NaN       NaN         NaN
# ...          ...        ...       ...         ...
# 4213  00978-0107        NaN       NaN         NaN
# 4214     T4b 1k3     Canada   51.3082   -114.0398
# 4215  00622-1942        NaN       NaN         NaN
# 4216   007729633        NaN       NaN         NaN
# 4217     M5V 1B2     Canada   43.6404    -79.3995
#
# [4218 rows x 4 columns]

# %%
df
# Out:
#          b2c_c2c  seller_id  ...  duration Is_within_US
# 0            B2C      25454  ...         3         True
# 1            C2C    6727381  ...         3         True
# 2            B2C      18507  ...         3         True
# 3            B2C       4677  ...         4         True
# 4            B2C       4677  ...         3         True
# ...          ...        ...  ...       ...          ...
# 14999995     B2C      80139  ...         3         True
# 14999996     C2C     452486  ...         6         True
# 14999997     B2C      43307  ...         5         True
# 14999998     B2C      24235  ...         3        False
# 14999999     C2C     535916  ...         4         True
#
# [15000000 rows x 50 columns]

# %%
pip install mpu
# Out:
# Collecting mpu
#   Downloading mpu-0.23.1-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 4.5 MB/s
# Installing collected packages: mpu
# Successfully installed mpu-0.23.1

# %%
df

# %%
def get_global_distance(seller, buyer):

# %%
missing_dist
# Out:
#          b2c_c2c  seller_id  ...  delivery_date2 duration
# 261          B2C     158262  ...      2018-06-04        5
# 318          B2C        692  ...      2018-04-17        1
# 561          B2C        400  ...      2018-06-28        2
# 597          B2C      49903  ...      2018-03-03        2
# 760          B2C      45133  ...      2018-11-15        2
# ...          ...        ...  ...             ...      ...
# 14999786     B2C        535  ...      2018-05-11        8
# 14999839     B2C        844  ...      2018-06-04        4
# 14999992     B2C         20  ...      2018-05-18        4
# 14999994     B2C      28583  ...      2018-05-17        6
# 14999998     B2C      24235  ...      2018-12-20        3
#
# [179057 rows x 43 columns]

# %%
missing_seller =  missing_dist[missing_dist['item_state'].isnull()]
missing_buyer =  missing_dist[missing_dist['buyer_state'].isnull()]
lst_missing = missing_seller['item_zip'].to_list() + missing_buyer['buyer_zip'].to_list()

# %%
df_missing = pd.DataFrame({'missing_zip': lst_missing})

# %%
unique_missing = df_missing['missing_zip'].unique()

# %%
import math

# %%
'''

def get_country_code(zip_code):
  
  for i in pgeocode.COUNTRIES_VALID:
    nomi = pgeocode.Nominatim(i)
   # this code will always return a dataframe
   # if the postal_code has no match, the df values will all be NaN 
    df = nomi.query_postal_code(zip_code)
    if type(df.country_code) == str:
      return df.country_code, df.latitude, df.longitude

def get_location_for_array(lst):
  state_name = []
  latitude = []
  longtitude = []
  for i in lst:
    try: 
      state, la, long = get_country_code(i)
      state_name.append(state)
      latitude.append(la)
      longtitude.append(long)
      print('{} th one is done'.format(i))
    except:
      state_name.append(float('nan'))
      latitude.append(float('nan'))
      longtitude.append(float('nan'))
      print('{} th one is done'.format(i))
    
  info = { 'missing_zip': lst , 'state_name' : state_name,
        'latitude': latitude,
        'longtitude': longtitude
       }

  df_new = pd.DataFrame.from_dict(info)
  df_new.to_csv('missing_new.csv')
  return df_new

'''

# %%
print(get_country_code('00627'))
# Out:
# /usr/local/lib/python3.7/dist-packages/pgeocode.py:204: UserWarning: The Argentina data file contains 4-digit postal codes which were replaced with a new system in 1999.
#   "The Argentina data file contains 4-digit postal "
# postal_code         00627
# country_code           PR
# place_name          Camuy
# state_name          Camuy
# state_code             27
# county_name           NaN
# county_code           NaN
# community_name        NaN
# community_code        NaN
# latitude          18.4838
# longitude        -66.8449
# accuracy                4
# Name: 0, dtype: object

# %%
print(get_country_code('050000'))
# Out:
# /usr/local/lib/python3.7/dist-packages/pgeocode.py:204: UserWarning: The Argentina data file contains 4-digit postal codes which were replaced with a new system in 1999.
#   "The Argentina data file contains 4-digit postal "
# None

# %%
lst_foreign_seller
# Out:
# array(['00627', '518000', '518000', ..., 'NE21YB', '91720', '510000'],
#       dtype=object)

# %%
df_seller = get_location_for_array(unique_missing)
# Out:
# /usr/local/lib/python3.7/dist-packages/pgeocode.py:204: UserWarning: The Argentina data file contains 4-digit postal codes which were replaced with a new system in 1999.
#   "The Argentina data file contains 4-digit postal "
# 00627 th one is done
# 518000 th one is done
# 510420 th one is done
# 610000 th one is done
# 510655 th one is done
# 45418 th one is done
# 52582 th one is done
# 213138 th one is done
# 45188 th one is done
# 316000 th one is done
# 518109 th one is done
# 518057 th one is done
# 1710014 th one is done
# 518116 th one is done
# 528000 th one is done
# 000 th one is done
# 516555 th one is done
# default th one is done
# 511400 th one is done
# 510000 th one is done
# 312000 th one is done
# 518001 th one is done
# 518108 th one is done
# 079903 th one is done
# 330004 th one is done
# 362000 th one is done
# 518103 th one is done
# Guangdong th one is done
# 40800 th one is done
# 518129 th one is done
# 515121 th one is done
# 518028 th one is done
# 230000 th one is done
# 18541 th one is done
# 518100 th one is done
# 510665 th one is done
# 116100 th one is done
# 930-0269 th one is done
# 112007 th one is done
# 650000 th one is done
# 700000 th one is done
# 88010 th one is done
# 510800 th one is done
# 00953-9333 th one is done
# 009539333 th one is done
# 85218 th one is done
# 336000 th one is done
# 323900 th one is done
# 528248 th one is done
# SN8 2BA th one is done
# 350007 th one is done
# 467221 th one is done
# 310000 th one is done
# 361005 th one is done
# M27 8SE th one is done
# 361000 th one is done
# 00916 th one is done
# 深圳 th one is done
# 364000 th one is done
# 545000 th one is done
# 543003 th one is done
# 102206 th one is done
# 7752511 th one is done
# 528400 th one is done
# 00730 th one is done
# 94101 th one is done
# 790000 th one is done
# 510725 th one is done
# 350001 th one is done
# 518052 th one is done
# 518029 th one is done
# 450000 th one is done
# 519000 th one is done
# 266000 th one is done
# 528463 th one is done
# 1770035 th one is done
# 322000 th one is done
# hp66rx th one is done
# 102200 th one is done
# 518118 th one is done
# 201617 th one is done
# 523841 th one is done
# 007150443 th one is done
# 96884 th one is done
# 550001 th one is done
# 518101 th one is done
# 523808 th one is done
# 200000 th one is done
# 518053 th one is done
# 1012 th one is done
# 323913 th one is done
# 65126 th one is done
# 95806 th one is done
# 518110 th one is done
# 200002 th one is done
# 201505 th one is done
# 17530 th one is done
# 71934 th one is done
# 11908 th one is done
# 55555 th one is done
# 215123 th one is done
# 30001 th one is done
# ST6 2BG th one is done
# 510660 th one is done
# 461000 th one is done
# 6777135 th one is done
# 518131 th one is done
# 47188 th one is done
# 529000 th one is done
# 210000 th one is done
# 10000 th one is done
# 621000 th one is done
# 430000 th one is done
# 77100 th one is done
# 177-0035 th one is done
# 1020 th one is done
# 223700 th one is done
# 518112 th one is done
# 92412 th one is done
# 050000 th one is done
# 371000 th one is done
# 528200 th one is done
# 51800 th one is done
# 33333 th one is done
# 431911 th one is done
# 518106 th one is done
# 215000 th one is done
# 330000 th one is done
# 215101 th one is done
# 85278 th one is done
# 226004 th one is done
# 77600 th one is done
# H4X 1M8 th one is done
# MD-2075 th one is done
# 1400 th one is done
# 00685 th one is done
# 400016 th one is done
# 343000 th one is done
# 70000 th one is done
# 02101 th one is done
# DY4 7DQ th one is done
# 96787 th one is done
# 00688-9714 th one is done
# 518004 th one is done
# 60290 th one is done
# 518133 th one is done
# 221000 th one is done
# 510175 th one is done
# 518048 th one is done
# 523710 th one is done
# 4275157 th one is done
# 332000 th one is done
# 523000 th one is done
# 29952 th one is done
# 511458 th one is done
# 518107 th one is done
# 0000 th one is done
# 0755 th one is done
# 22703 th one is done
# 518031 th one is done
# 92569 th one is done
# 547000 th one is done
# 2565 th one is done
# 066000 th one is done
# 214000 th one is done
# 230088 th one is done
# 91002 th one is done
# 25146 th one is done
# 80321 th one is done
# 264006 th one is done
# 230071 th one is done
# 21997 th one is done
# 365000 th one is done
# 400020 th one is done
# 066004 th one is done
# 6706440 th one is done
# 94406 th one is done
# 261000 th one is done
# 00641-2956 th one is done
# 150000 th one is done
# 150167 th one is done
# 406 th one is done
# 473000 th one is done
# 11248 th one is done
# 362321 th one is done
# 00602 th one is done
# 10640 th one is done
# dn36 4wn th one is done
# V7A 3B5 th one is done
# 441000 th one is done
# V6Y3A3 th one is done
# 518117 th one is done
# 252002 th one is done
# PO3 5RN th one is done
# 63553 th one is done
# 1000 th one is done
# 96921 th one is done
# 518060 th one is done
# 26100 th one is done
# 41633 th one is done
# 006769779 th one is done
# 510430 th one is done
# 518104 th one is done
# 239000 th one is done
# 331200 th one is done
# ls83bs th one is done
# 250000 th one is done
# 266555 th one is done
# 034000 th one is done
# 00795 th one is done
# 91718 th one is done
# 116001 th one is done
# 3000 th one is done
# 454550 th one is done
# G20 7LU th one is done
# 351100 th one is done
# 518125 th one is done
# 812 th one is done
# 95541 th one is done
# 402460 th one is done
# 6939527 th one is done
# 528500 th one is done
# 236000 th one is done
# 330 th one is done
# 518040 th one is done
# V1E 3H2 th one is done
# 116600 th one is done
# TN27 8JZ th one is done
# L3C 1Z2 th one is done
# 343802 th one is done
# 337000 th one is done
# 34055 th one is done
# 311323 th one is done
# EX48HH th one is done
# 51000 th one is done
# ne21yb th one is done
# 403 th one is done
# 龙岗区 th one is done
# 518046 th one is done
# 91760 th one is done
# 07226 th one is done
# 310001 th one is done
# 61000 th one is done
# 6083508 th one is done
# 201799 th one is done
# 96827 th one is done
# 68054 th one is done
# 361009 th one is done
# 117000 th one is done
# 537800 th one is done
# 510320 th one is done
# 529800 th one is done
# 528414 th one is done
# 47650 th one is done
# 52100 th one is done
# 521000 th one is done
# 401542 th one is done
# 410000 th one is done
# 6026032 th one is done
# 523690 th one is done
# 271000 th one is done
# T3K5A2 th one is done
# 325000 th one is done
# 418000 th one is done
# 00669 th one is done
# 33808 th one is done
# 90901 th one is done
# 00678 th one is done
# 518050 th one is done
# 518055 th one is done
# 7765493 th one is done
# 3229617 th one is done
# 31802 th one is done
# 626-797 th one is done
# 55221 th one is done
# 450100xin th one is done
# 670406 th one is done
# 68011 th one is done
# 262111 th one is done
# 313300 th one is done
# 10141 th one is done
# 518037 th one is done
# 523850 th one is done
# 2196 th one is done
# b113ep th one is done
# 43618 th one is done
# 60054 th one is done
# 969120273 th one is done
# 315000 th one is done
# 56112 th one is done
# l3r1e4 th one is done
# 518114 th one is done
# 441806 th one is done
# 90000 th one is done
# 524800 th one is done
# 550009 th one is done
# 518102 th one is done
# 170-0013 th one is done
# 410007 th one is done
# v3t 1h4 th one is done
# 45000 th one is done
# TN26 3SG th one is done
# 7645 th one is done
# 5851019 th one is done
# 28800 th one is done
# 302016 th one is done
# 009879791 th one is done
# 27091 th one is done
# 45427 th one is done
# 066006 th one is done
# 30659 th one is done
# 516700 th one is done
# 26315 th one is done
# 10240 th one is done
# 226315 th one is done
# 180000 th one is done
# 34100 th one is done
# 511500 th one is done
# 53112 th one is done
# 343801 th one is done
# 91621 th one is done
# 701000 th one is done
# 456001 th one is done
# 420000 th one is done
# 245000 th one is done
# 262400 th one is done
# 264000 th one is done
# 432000 th one is done
# 000000 th one is done
# 48962 th one is done
# 330800 th one is done
# 广东省 th one is done
# 518111 th one is done
# 22000 th one is done
# 354004 th one is done
# 325001 th one is done
# 00931-2967 th one is done
# 810000 th one is done
# 85000 th one is done
# 266300 th one is done
# 404 th one is done
# 00676-9779 th one is done
# 77839 th one is done
# 1403 th one is done
# 1111 th one is done
# 33110 th one is done
# 00725-5800 th one is done
# 021 th one is done
# 467000 th one is done
# 518115 th one is done
# 64610 th one is done
# 163000 th one is done
# 518049 th one is done
# L2r 1r0 th one is done
# 92795 th one is done
# 100000 th one is done
# 91191 th one is done
# 518013 th one is done
# 90441 th one is done
# 512023 th one is done
# L0R 1B3 th one is done
# 110000 th one is done
# 91720 th one is done
# B6 4TQ th one is done
# 94090 th one is done
# 99045 th one is done
# 19778 th one is done
# 518033 th one is done
# 31-081 th one is done
# 518003 th one is done
# 312570 th one is done
# 96882 th one is done
# 80000 th one is done
# 14583 th one is done
# 518124 th one is done
# 518122 th one is done
# 350000 th one is done
# g52 1JU th one is done
# 56391 th one is done
# 24159 th one is done
# 213000 th one is done
# 92621 th one is done
# v5s 2l3 th one is done
# bb31nr th one is done
# 100009 th one is done
# 160000 th one is done
# 33632 th one is done
# 96800 th one is done
# 00953 th one is done
# 201619 th one is done
# 67382 th one is done
# IG11 0TP th one is done
# 22880 th one is done
# 1024 th one is done
# 401120 th one is done
# 518034 th one is done
# 85242 th one is done
# 78262 th one is done
# 10430 th one is done
# 537000 th one is done
# 42800 th one is done
# 00969 th one is done
# 96929 th one is done
# 350028 th one is done
# 80367 th one is done
# 85222 th one is done
# 85455 th one is done
# 323003 th one is done
# 11708 th one is done
# 92194 th one is done
# 10392 th one is done
# 2143 th one is done
# 354502 th one is done
# 38484 th one is done
# 3173 th one is done
# 470074 th one is done
# HA4 9EQ th one is done
# 511442 th one is done
# 266426 th one is done
# 525200 th one is done
# 198283 th one is done
# 341000 th one is done
# T2Z2H2 th one is done
# 00956 th one is done
# 4145 th one is done
# 10250 th one is done
# 510002 th one is done
# 85219 th one is done
# 518126 th one is done
# 471000 th one is done
# 16152 th one is done
# 00688 th one is done
# LN5 0AG th one is done
# 433124 th one is done
# SN67PD th one is done
# 48904 th one is done
# PO2 8RW th one is done
# 511300 th one is done
# 335004 th one is done
# 2218 th one is done
# 101-0021 th one is done
# 96913 th one is done
# 800000 th one is done
# 0769 th one is done
# 85220 th one is done
# 225413 th one is done
# 528244 th one is done
# 4938508 th one is done
# 2000032 th one is done
# 353200 th one is done
# 6964314 th one is done
# W12 8LP th one is done
# M1H 2M1 th one is done
# 85228 th one is done
# 99127 th one is done
# 78476 th one is done
# 81948 th one is done
# 226000 th one is done
# 725007 th one is done
# 00782-0091 th one is done
# 00926 th one is done
# 98810 th one is done
# 00676 th one is done
# 00612 th one is done
# 11168 th one is done
# 54000 th one is done
# 051330 th one is done
# 528237 th one is done
# 475000 th one is done
# 431700 th one is done
# 063000 th one is done
# 512000 th one is done
# 63491 th one is done
# 0204 th one is done
# 60667 th one is done
# 65000 th one is done
# 42815 th one is done
# 33900 th one is done
# 71948 th one is done
# 90792 th one is done
# 520100 th one is done
# 433000 th one is done
# SM13DN th one is done
# 511430 th one is done
# 214400 th one is done
# 10388 th one is done
# ST6 4NQ th one is done
# 454000 th one is done
# 4150 th one is done
# 30050 th one is done
# 999077 th one is done
# 22621 th one is done
# 86356 th one is done
# 96688 th one is done
# 11000 th one is done
# 90902 th one is done
# 255000 th one is done
# 110166 th one is done
# 7169700 th one is done
# L3S1X6 th one is done
# 518081 th one is done
# 00000 th one is done
# 215008 th one is done
# 511340 th one is done
# 34861 th one is done
# 321036 th one is done
# V2X 7X0 th one is done
# SW17 9QX th one is done
# L6M1J8 th one is done
# cm203nj th one is done
# 050056 th one is done
# 201615 th one is done
# 41307 th one is done
# 41000 th one is done
# 98442 th one is done
# 45110 th one is done
# 00705 th one is done
# 510130 th one is done
# 102208 th one is done
# 104 th one is done
# 330009 th one is done
# 3752 th one is done
# SO15 1HN th one is done
# 519075 th one is done
# 510170 th one is done
# 51100 th one is done
# 571000 th one is done
# 59506 th one is done
# 90654 th one is done
# 523999 th one is done
# 760329 th one is done
# 64700 th one is done
# 03747 th one is done
# 40494 th one is done
# 28808 th one is done
# 518027 th one is done
# 870000 th one is done
# 7621770 th one is done
# 610051 th one is done
# 1528 th one is done
# 350026 th one is done
# 518067 th one is done
# 852 th one is done
# 53995 th one is done
# 223800 th one is done
# 020 th one is done
# 510650 th one is done
# 01995 th one is done
# 530000 th one is done
# 47100 th one is done
# 46000 th one is done
# 33628 th one is done
# M9L 1V7 th one is done
# 00924 th one is done
# 41705710 th one is done
# 116000 th one is done
# 13971 th one is done
# 9339221 th one is done
# 3011 th one is done
# 00662 th one is done
# 33344 th one is done
# 510700 th one is done
# 57171 th one is done
# 98460 th one is done
# 85230 th one is done
# 29535 th one is done
# 311815 th one is done
# 2443 th one is done
# 广东 th one is done
# 13430 th one is done
# 40000 th one is done
# 334000 th one is done
# 52952 th one is done
# 85288 th one is done
# 00926-2523 th one is done
# 46424 th one is done
# 33690 th one is done
# 43288 th one is done
# 518025 th one is done
# 3758 th one is done
# 21416 th one is done
# 2278 th one is done
# cf83 3lp th one is done
# 114 th one is done
# 8203 th one is done
# 315300 th one is done
# 77526 th one is done
# 22012 th one is done
# 3175 th one is done
# 2811601 th one is done
# 98180 th one is done
# 184855 th one is done
# 381400 th one is done
# 5181000 th one is done
# 528467 th one is done
# 321000 th one is done
# L3R 1H3 th one is done
# TF1 1NE th one is done
# 448-831 th one is done
# 90344 th one is done
# 815000 th one is done
# LE3 8DX th one is done
# 233000 th one is done
# 71514 th one is done
# 110007 th one is done
# 590000 th one is done
# 33447 th one is done
# 10210 th one is done
# 354000 th one is done
# 11986 th one is done
# T2C1V3 th one is done
# 525000 th one is done
# 30600 th one is done
# 830000 th one is done
# 6280 th one is done
# 214151 th one is done
# 28830 th one is done
# 85238 th one is done
# 28200 th one is done
# 8050 th one is done
# M50 2UE th one is done
# L7C 1M2 th one is done
# 4857040 th one is done
# 343200 th one is done
# 2914 th one is done
# 62130 th one is done
# 311100 th one is done
# 6100 th one is done
# 118100 th one is done
# 5000 th one is done
# 2019 th one is done
# 49652 th one is done
# 93889 th one is done
# 363000 th one is done
# 85223 th one is done
# 708000 th one is done
# 323911 th one is done
# 130500 th one is done
# 518128 th one is done
# 0591 th one is done
# 00674-9761 th one is done
# 122002 th one is done
# 464000 th one is done
# 362400 th one is done
# 7008 th one is done
# 518024 th one is done
# LE67 1LD th one is done
# 60000 th one is done
# 00949 th one is done
# 518300 th one is done
# 510663 th one is done
# V5J 5H8 th one is done
# 40640 th one is done
# 6083646 th one is done
# 472-795 th one is done
# 66134 th one is done
# 80242 th one is done
# 410-837 th one is done
# 82211 th one is done
# 42835 th one is done
# 311321 th one is done
# 11140 th one is done
# 15326 th one is done
# 00662-3882 th one is done
# 36000 th one is done
# 421000 th one is done
# 518083 th one is done
# 516023 th one is done
# 8481973 th one is done
# 75531 th one is done
# 30900 th one is done
# 8436716 th one is done
# 511486 th one is done
# 518020 th one is done
# 40112 th one is done
# 12888 th one is done
# 72691 th one is done
# M8 8HF th one is done
# 322008 th one is done
# 10146 th one is done
# 6200 th one is done
# 5180000 th one is done
# 50343 th one is done
# 412000 th one is done
# 339006 th one is done
# 3904 th one is done
# 10837 th one is done
# 518010 th one is done
# 510720 th one is done
# 523900 th one is done
# 金华 th one is done
# 00052 th one is done
# 17 th one is done
# 5045 th one is done
# 1870 th one is done
# 4990-036 th one is done
# 028006 th one is done
# 312300 th one is done
# 30201 th one is done
# 06748 th one is done
# 260000 th one is done
# 12000 th one is done
# 39142 th one is done
# 45100 th one is done
# 919191 th one is done
# 112008 th one is done
# 36138 th one is done
# 2150 th one is done
# 84200 th one is done
# 342715 th one is done
# 250100 th one is done
# 200949 th one is done
# 55198 th one is done
# 2065 th one is done
# ng5 3bg th one is done
# 343617 th one is done
# 0377 th one is done
# 11512 th one is done
# 519070 th one is done
# 76100 th one is done
# 110091 th one is done
# 510006 th one is done
# 272100 th one is done
# GU2 9LA th one is done
# 1878918 th one is done
# 76304 th one is done
# 60500 th one is done
# 9010 th one is done
# 4445-199 th one is done
# 10100 th one is done
# 1441216 th one is done
# 38678 th one is done
# 90103 th one is done
# 83621 th one is done
# 3087000 th one is done
# 00670 th one is done
# 523700 th one is done
# SN3 6ND th one is done
# j7k2x4 th one is done
# 88091 th one is done
# 529931 th one is done
# 2602 th one is done
# 52000 th one is done
# 00676-8368 th one is done
# 9779268 th one is done
# 18984 th one is done
# 760003 th one is done
# 16119 th one is done
# 08100 th one is done
# LT-14113 th one is done
# 302021 th one is done
# 933 th one is done
# b178lh th one is done
# 77247 th one is done
# CW8 3LZ th one is done
# 00693 th one is done
# 211101 th one is done
# 7500 th one is done
# L1T4W8 th one is done
# 28322 th one is done
# 20000 th one is done
# 00778-0426 th one is done
# 2222 th one is done
# 73000 th one is done
# 33159 th one is done
# 010 th one is done
# 4000 th one is done
# 1100000 th one is done
# 55000 th one is done
# 29408 th one is done
# 400000 th one is done
# 516002 th one is done
# 61212 th one is done
# N0N 1E0 th one is done
# 11064 th one is done
# L3R 0S9 th one is done
# 28013 th one is done
# 730000 th one is done
# 60386 th one is done
# 16129 th one is done
# 341214 th one is done
# 73410 th one is done
# 10048 th one is done
# 17666 th one is done
# 476613 th one is done
# 88015 th one is done
# 560000 th one is done
# 00678-2541 th one is done
# 221 th one is done
# 241 th one is done
# 5849954 th one is done
# 68200 th one is done
# 7540620 th one is done
# 410326 th one is done
# 84000 th one is done
# 88888 th one is done
# 60850 th one is done
# 2526 th one is done
# 02727 th one is done
# 32500 th one is done
# 63001 th one is done
# 516000 th one is done
# 201501 th one is done
# 95783 th one is done
# 64944 th one is done
# 98205 th one is done
# 55028 th one is done
# L3R 9W6 th one is done
# 428021 th one is done
# 92–7o th one is done
# 350125 th one is done
# 434000 th one is done
# 85227 th one is done
# 7692000 th one is done
# 92000 th one is done
# 00966 th one is done
# 17620 th one is done
# 820000 th one is done
# 96915 th one is done
# 00718-0475 th one is done
# 5243331 th one is done
# 7270 th one is done
# 13500 th one is done
# 82000 th one is done
# 47939 th one is done
# 53244 th one is done
# 529500 th one is done
# 598-0037 th one is done
# 56746 th one is done
# 264200 th one is done
# H1Z3K4 th one is done
# 51121 th one is done
# 12276 th one is done
# 19750 th one is done
# 46010 th one is done
# 63593 th one is done
# h3e 1b8 th one is done
# 8425555 th one is done
# 44300 th one is done
# 53000 th one is done
# 52503 th one is done
# 60272 th one is done
# Pl15 8bq th one is done
# 150006 th one is done
# 7550977 th one is done
# 460000 th one is done
# 1000000 th one is done
# W14 8DA th one is done
# 350500 th one is done
# L1Z2C3 th one is done
# AB155LZ th one is done
# 4939010 th one is done
# 518038 th one is done
# 525100 th one is done
# 5385 th one is done
# 611743 th one is done
# 425500 th one is done
# 510640 th one is done
# 524500 th one is done
# 26000000 th one is done
# 9962 th one is done
# 1220 th one is done
# 529100 th one is done
# 40123 th one is done
# 3023 th one is done
# 528325 th one is done
# 22510 th one is done
# 543001 th one is done
# 99120 th one is done
# 19766 th one is done
# H3M 1X3 th one is done
# 4400 th one is done
# 10410 th one is done
# 00727 th one is done
# 1752616 th one is done
# 462000 th one is done
# 31000 th one is done
# T0L2H0 th one is done
# 45447 th one is done
# 90705 th one is done
# 215131 th one is done
# 65153 th one is done
# H4L 4V4 th one is done
# 400056 th one is done
# E10 7QZ th one is done
# 536000 th one is done
# 34562 th one is done
# 71700 th one is done
# L2R1R5 th one is done
# 3156 th one is done
# 69115 th one is done
# 25150 th one is done
# 00683 th one is done
# 214100 th one is done
# 511450 th one is done
# 16000 th one is done
# 637000 th one is done
# SM6 5TA th one is done
# 135-0064 th one is done
# 00704 th one is done
# RH4 3HP th one is done
# 50000 th one is done
# 24229 th one is done
# 46264 th one is done
# 01580 th one is done
# 32600 th one is done
# 516082 th one is done
# 526112 th one is done
# 91272 th one is done
# 15811 th one is done
# 4935435 th one is done
# 83130 th one is done
# 66120 th one is done
# Dublin th one is done
# SN15 1PA th one is done
# 518056 th one is done
# 061000 th one is done
# 33000 th one is done
# PR7 3HU th one is done
# 450003 th one is done
# 280000 th one is done
# UB2 5LF th one is done
# 19661 th one is done
# 9450 th one is done
# N17 8LH th one is done
# 03000 th one is done
# 600001 th one is done
# M1R3E4 th one is done
# L3R1H3 th one is done
# 199106 th one is done
# 006857005 th one is done
# 29308 th one is done
# 1050 th one is done
# 302019 th one is done
# 445000 th one is done
# 93000 th one is done
# 53100 th one is done
# 05247 th one is done
# 00927 th one is done
# 91795 th one is done
# 00678-2600 th one is done
# CB6 1NZ th one is done
# 130051 th one is done
# 75295 th one is done
# 85245 th one is done
# 51831 th one is done
# 518059 th one is done
# 余杭区 th one is done
# 30027 th one is done
# 8486803 th one is done
# 7740808 th one is done
# lv-1015 th one is done
# 28197 th one is done
# N5X4G5 th one is done
# 91243 th one is done
# 76646 th one is done
# 59567 th one is done
# 610031 th one is done
# 215100 th one is done
# 75257 th one is done
# 236800 th one is done
# 617000 th one is done
# 24152 th one is done
# 350008 th one is done
# 710000 th one is done
# Dublin 10 th one is done
# 77439 th one is done
# 85239 th one is done
# 518105 th one is done
# LV-4201 th one is done
# 813 th one is done
# 510425 th one is done
# 75400 th one is done
# 38809 th one is done
# 27345 th one is done
# 115000 th one is done
# 94013 th one is done
# 08017 th one is done
# 26333 th one is done
# 3305 th one is done
# M27 6DB th one is done
# 2005 th one is done
# 92900 th one is done
# L2T 3P8 th one is done
# 324416 th one is done
# GU1 1RU th one is done
# 515000 th one is done
# 133001 th one is done
# L4S 2A2 th one is done
# 360010 th one is done
# EN8 8BT th one is done
# 2071 th one is done
# 518007 th one is done
# 3629 th one is done
# 528411 th one is done
# 18048 th one is done
# 354500 th one is done
# 49551 th one is done
# 2474 th one is done
# S4R 1E7 th one is done
# 00791-9039 th one is done
# 3570527 th one is done
# 10700 th one is done
# 210048 th one is done
# 5248228 th one is done
# NE66 6PD th one is done
# 110821 th one is done
# 026000 th one is done
# 528231 th one is done
# 44369 th one is done
# 30330 th one is done
# 1010 th one is done
# 22500 th one is done
# 326000 th one is done
# 12113 th one is done
# 48100 th one is done
# 22132 th one is done
# 224001 th one is done
# TS148AU th one is done
# V6P3H4 th one is done
# 6239 th one is done
# V5Y2K5 th one is done
# 1310042 th one is done
# L6S 6E8 th one is done
# 92952 th one is done
# M2H 3A9 th one is done
# 31610 th one is done
# 813700 th one is done
# 25256 th one is done
# 2483 th one is done
# L4E 1A2 th one is done
# 450002 th one is done
# 7224145 th one is done
# 10400 th one is done
# 414000 th one is done
# T2Z0M5 th one is done
# 34424 th one is done
# 364111 th one is done
# 66490 th one is done
# 10330 th one is done
# 6424523 th one is done
# 503 th one is done
# 201620 th one is done
# 4238661 th one is done
# 60271 th one is done
# 7828102 th one is done
# 51042 th one is done
# 330002 th one is done
# 4901 th one is done
# 30210 th one is done
# 2580-408 th one is done
# 42842 th one is done
# 98706 th one is done
# 12756 th one is done
# 66811 th one is done
# PL15 8GX th one is done
# 85100 th one is done
# DUBLIN15 th one is done
# 4639814 th one is done
# so50 6gu th one is done
# 50221 th one is done
# 520000 th one is done
# 73225 th one is done
# Mundingen th one is done
# 343800 th one is done
# 77826 th one is done
# 1073 th one is done
# 80343 th one is done
# 20400 th one is done
# M33 5BW th one is done
# 65659 th one is done
# 28022 th one is done
# 50267 th one is done
# 331209 th one is done
# 93911 th one is done
# 3430 th one is done
# 10015 th one is done
# 109457 th one is done
# 332400 th one is done
# 92889 th one is done
# 410206 th one is done
# 52300 th one is done
# 448000 th one is done
# 3149 th one is done
# 55233 th one is done
# 47098 th one is done
# 511431 th one is done
# MD-2001 th one is done
# 重庆市 th one is done
# 302006 th one is done
# L4A 0L9 th one is done
# 518042 th one is done
# 00981-0135 th one is done
# 30051 th one is done
# 6941218 th one is done
# 17152 th one is done
# LV-4583 th one is done
# 570000 th one is done
# 266061 th one is done
# 22110 th one is done
# 39103 th one is done
# 2232516 th one is done
# 380000 th one is done
# 90101 th one is done
# 84798 th one is done
# 50300 th one is done
# 92745 th one is done
# V6P 2V5 th one is done
# 27432 th one is done
# 54317 th one is done
# 519060 th one is done
# 00617-3550 th one is done
# 518035 th one is done
# 7766722 th one is done
# 40465 th one is done
# 85156 th one is done
# 92302 th one is done
# 8429219 th one is done
# 02068 th one is done
# 550000 th one is done
# M1S2Z9 th one is done
# ss15 6al th one is done
# 22069 th one is done
# 520145 th one is done
# 1215 th one is done
# 7534152 th one is done
# 1515000 th one is done
# 57154 th one is done
# M9W 6P2 th one is done
# 518017 th one is done
# 78474 th one is done
# 519100 th one is done
# 14256 th one is done
# MK41 0PG th one is done
# N0N1C0 th one is done
# 33216199 th one is done
# 440000 th one is done
# Sy45es th one is done
# 94003 th one is done
# 04060 th one is done
# 00920-5613 th one is done
# 355009 th one is done
# 02781 th one is done
# 37249 th one is done
# 523635 th one is done
# 宝安区 th one is done
# 315040 th one is done
# 58000 th one is done
# 76056 th one is done
# 3584910 th one is done
# V3M6S5 th one is done
# 545002 th one is done
# 215144 th one is done
# 8320000 th one is done
# 006831580 th one is done
# 00682 th one is done
# L3R1J5 th one is done
# 30500 th one is done
# 418113 th one is done
# 065000 th one is done
# 60635 th one is done
# 266033 th one is done
# 527235 th one is done
# 37346 th one is done
# M1P 3E6 th one is done
# 02000 th one is done
# 91463 th one is done
# 0575 th one is done
# 3464305 th one is done
# 44801 th one is done
# 57000 th one is done
# 65176 th one is done
# 40191 th one is done
# 53638 th one is done
# 4230 th one is done
# 450004 th one is done
# 840000 th one is done
# 611230 th one is done
# 96912 th one is done
# PR43+6X th one is done
# T0H 3N0 th one is done
# 47195 th one is done
# CF631DL th one is done
# 93632 th one is done
# 21584 th one is done
# 523110 th one is done
# 00667 th one is done
# 6056 th one is done
# 70800 th one is done
# J0L1N0 th one is done
# 220000 th one is done
# 518030 th one is done
# L4K2C8 th one is done
# 77300 th one is done
# 28249 th one is done
# 170000 th one is done
# 06497 th one is done
# 201612 th one is done
# 47105 th one is done
# 91462 th one is done
# 187330 th one is done
# 0579 th one is done
# 76620 th one is done
# 00698 th one is done
# 61200 th one is done
# 19722 th one is done
# 41860 th one is done
# 60049 th one is done
# 4573 th one is done
# 5403845 th one is done
# H9S4W3 th one is done
# 35018 th one is done
# 00660 th one is done
# 52150 th one is done
# 13015 th one is done
# 36731 th one is done
# 00617 th one is done
# 006749761 th one is done
# 311601 th one is done
# LS12 6AJ th one is done
# 332621 th one is done
# l5m0g6 th one is done
# 92353 th one is done
# 72000 th one is done
# PA29 6TX th one is done
# 311200 th one is done
# 74246 th one is done
# 98184 th one is done
# 153-803 th one is done
# 518014 th one is done
# 42382 th one is done
# 215633 th one is done
# 0768 th one is done
# 48241 th one is done
# 518518 th one is done
# V5V 3A9 th one is done
# 02158 th one is done
# me71dj th one is done
# 00953-3602 th one is done
# 247001 th one is done
# 3433 PL th one is done
# 8489327 th one is done
# 1240022 th one is done
# 38110 th one is done
# 360000 th one is done
# 510830 th one is done
# K2P 0C7 th one is done
# 1800 th one is done
# 422-707 th one is done
# 57711 th one is done
# 630001 th one is done
# המיקוד לכתוב th one is done
# 5100000 th one is done
# 00680-9998 th one is done
# 00792-0675 th one is done
# 991-0063 th one is done
# 80-390 th one is done
# 52130 th one is done
# W1F 9BP th one is done
# 7534144 th one is done
# 55755 th one is done
# 511449 th one is done
# 8000 th one is done
# 00074 th one is done
# 00988 th one is done
# 89190 th one is done
# 3077 th one is done
# 53273 th one is done
# HA8 7EB th one is done
# 581000 th one is done
# 2131 th one is done
# 200940 th one is done
# 51356 th one is done
# 65312 th one is done
# 41313 th one is done
# SG6 2SF th one is done
# 4283500 th one is done
# SY22 5EW th one is done
# 3125102 th one is done
# 11314 th one is done
# 19874 th one is done
# H4T1X8 th one is done
# 23132 th one is done
# 644085 th one is done
# 29751 th one is done
# 11748 th one is done
# 7528813 th one is done
# 518023 th one is done
# 55881 th one is done
# n5 2hd th one is done
# 700135 th one is done
# 4917001 th one is done
# 07610 th one is done
# 82165 th one is done
# 35247 th one is done
# 95849 th one is done
# 83000 th one is done
# 537100 th one is done
# 690106 th one is done
# 8155351 th one is done
# 37990 th one is done
# 4079009 th one is done
# 518173 th one is done
# 22322 th one is done
# 151074 th one is done
# 65821 th one is done
# 0791 th one is done
# 16174 th one is done
# 414353 th one is done
# 528225 th one is done
# 53300 th one is done
# 00202 th one is done
# 7408605 th one is done
# 07550 th one is done
# 95588 th one is done
# M1H2M1 th one is done
# 91798 th one is done
# 51200 th one is done
# 00677-2447 th one is done
# 644086 th one is done
# V1E4G9 th one is done
# 184800 th one is done
# N.A. th one is done
# 66877 th one is done
# 13380 th one is done
# 30020 th one is done
# 201000 th one is done
# 96920 th one is done
# 00603-9740 th one is done
# 530004 th one is done
# 579000 th one is done
# 40300 th one is done
# 76297 th one is done
# 243071 th one is done
# 195274 th one is done
# 4424615 th one is done
# K2T 0A3 th one is done
# 6081240 th one is done
# 30387 th one is done
# 43098 th one is done
# 528311 th one is done
# 20290 th one is done
# 13231 th one is done
# 00727-5706 th one is done
# 9768 th one is done
# 670000 th one is done
# 91494 th one is done
# 7842178 th one is done
# 88084 th one is done
# 22222 th one is done
# PO9 2NJ th one is done
# 42114 th one is done
# 610036 th one is done
# 63317 th one is done
# 518032 th one is done
# 214001 th one is done
# J7B 1X7 th one is done
# 2600 th one is done
# 75286 th one is done
# 86150 th one is done
# sw10 9hn th one is done
# 2001 th one is done
# 2211 th one is done
# 7849713 th one is done
# L6A4E8 th one is done
# 17510 th one is done
# 9636302 th one is done
# 4937314 th one is done
# 00613-2855 th one is done
# 516009 th one is done
# 330038 th one is done
# 20300 th one is done
# 60216 th one is done
# M137JQ th one is done
# 61950 th one is done
# 52422 th one is done
# 4113 th one is done
# 96153 th one is done
# 560053 th one is done
# 214500 th one is done
# 511452 th one is done
# 523430 th one is done
# 197720 th one is done
# 610041 th one is done
# 35713 th one is done
# 28195 th one is done
# 48078 th one is done
# 94831 th one is done
# L0S 1E5 th one is done
# 448124 th one is done
# 450100 th one is done
# 625000 th one is done
# 59573 th one is done
# 00719-9787 th one is done
# N3H 3M9 th one is done
# 92326 th one is done
# GU22 0PY th one is done
# 85240 th one is done
# HP18 0HR th one is done
# 350004 th one is done
# 21352 th one is done
# 00821 th one is done
# 04759 th one is done
# L 15 th one is done
# E15 1QX th one is done
# G2 0NA th one is done
# 33962 th one is done
# 55181 th one is done
# 00923-1243 th one is done
# 65365 th one is done
# 4922373 th one is done
# 066400 th one is done
# 07794 th one is done
# _UAES_NULL_ th one is done
# 27220 th one is done
# 83410 th one is done
# 1134 th one is done
# 72258 th one is done
# MD2005 th one is done
# 320000 th one is done
# 4009 th one is done
# NW11 0JN th one is done
# 34944 th one is done
# 2850 th one is done
# 42251 th one is done
# 30278 th one is done
# TN37 7JZ th one is done
# 5201 th one is done
# 37239 th one is done
# 00901 th one is done
# 518054 th one is done
# 85232 th one is done
# 07282 th one is done
# 318000 th one is done
# 11820A th one is done
# 86000 th one is done
# 40400 th one is done
# 41904 th one is done
# 33121 th one is done
# 43850 th one is done
# 6940204 th one is done
# 852000 th one is done
# 529321 th one is done
# Az1000 th one is done
# 2726 th one is done
# 44322 th one is done
# 419283 th one is done
# 390010 th one is done
# 53313 th one is done
# 4020 th one is done
# 94106 th one is done
# 111111 th one is done
# 21395 th one is done
# 143900 th one is done
# 450008 th one is done
# 300000 th one is done
# 18715 th one is done
# 10905 th one is done
# 449293 th one is done
# 62318 th one is done
# 23159 th one is done
# 528303 th one is done
# 26450 th one is done
# NG14 5AB th one is done
# 34000 th one is done
# PR31PR th one is done
# 431710 th one is done
# 5101 th one is done
# CP 1601 th one is done
# 399849 th one is done
# 518016 th one is done
# 4250567 th one is done
# 20023 th one is done
# SE26 5HX th one is done
# 311602 th one is done
# 87906 th one is done
# 529030 th one is done
# 81966 th one is done
# M2J4V6 th one is done
# 00784 th one is done
# 19483 th one is done
# 98423 th one is done
# Lu2 8nx th one is done
# 35512 th one is done
# 85642 th one is done
# 76829 th one is done
# 362199 th one is done
# 52474 th one is done
# 7662060 th one is done
# 518006 th one is done
# 03728 th one is done
# 646000 th one is done
# 518172 th one is done
# 325003 th one is done
# 00984 th one is done
# 42186 th one is done
# N16 5PT th one is done
# 16431 th one is done
# 52365 th one is done
# 00792 th one is done
# 9382629 th one is done
# 80100 th one is done
# 65701 th one is done
# 44852 th one is done
# 4077625 th one is done
# 2155 th one is done
# 480000 th one is done
# 19640 th one is done
# 362200 th one is done
# 580000 th one is done
# 510780 th one is done
# 1001 th one is done
# 80060 th one is done
# 007710577 th one is done
# 5958151 th one is done
# 8709087 th one is done
# 97299 th one is done
# 36422 th one is done
# M1V2E9 th one is done
# 165-0027 th one is done
# 52117 th one is done
# 276800 th one is done
# 110861 th one is done
# 3053 th one is done
# 200233 th one is done
# 5115 th one is done
# 624096 th one is done
# LE19 2BA th one is done
# 10600 th one is done
# 311201 th one is done
# 99041 th one is done
# 240000 th one is done
# L5M6J6 th one is done
# po3 5fl th one is done
# 3941 th one is done
# 4952039 th one is done
# 86862 th one is done
# 76546 th one is done
# 92813 th one is done
# 35240 th one is done
# 528478 th one is done
# 86479 th one is done
# 032704 th one is done
# 09300 th one is done
# L3R9W6 th one is done
# 70300 th one is done
# 11388 th one is done
# 520240 th one is done
# 344000 th one is done
# 518036 th one is done
# 54367 th one is done
# 54719 th one is done
# 45408 th one is done
# 7842003 th one is done
# SR4 7TW th one is done
# 11410A th one is done
# 4252464 th one is done
# Barendrecht th one is done
# 40835 th one is done
# 51515 th one is done
# 48305 th one is done
# 15000 th one is done
# 3029 th one is done
# AB10 1YP th one is done
# 01200 th one is done
# 137030 th one is done
# 26000 th one is done
# 1230 th one is done
# 98718 th one is done
# 85440 th one is done
# 690000 th one is done
# E1W 5V7 th one is done
# 52470 th one is done
# 482000 th one is done
# 052400 th one is done
# 8996202 th one is done
# 42490 th one is done
# Ch87hz th one is done
# 7080000 th one is done
# 76332 th one is done
# 11382 th one is done
# 410847 th one is done
# 20100 th one is done
# 00613 th one is done
# 1210 th one is done
# 170 th one is done
# 312500 th one is done
# 5227320 th one is done
# 518132 th one is done
# 58326 th one is done
# 90789 th one is done
# 63322 th one is done
# 6771409 th one is done
# 32575 th one is done
# V4C 4S2 th one is done
# S6H 1X8 th one is done
# 7004 th one is done
# 224000 th one is done
# 7696500 th one is done
# 536842 th one is done
# 6300 th one is done
# 00970 th one is done
# 54294 th one is done
# 00927-6734 th one is done
# 79320 th one is done
# 63371 th one is done
# 68211 th one is done
# 8400 th one is done
# 98888 th one is done
# 6424710 th one is done
# 94646 th one is done
# 上海 th one is done
# 87626 th one is done
# 46768 th one is done
# 7976 th one is done
# 57672 th one is done
# 302004 th one is done
# 12600 th one is done
# 67251 th one is done
# 4852005 th one is done
# 76897 th one is done
# 0757 th one is done
# 13710 th one is done
# 7402558 th one is done
# 6217 th one is done
# 24000 th one is done
# 90616 th one is done
# BT41 4LD th one is done
# 986547 th one is done
# 00739 th one is done
# Sp10 1ry th one is done
# 49524 th one is done
# 312365 th one is done
# 630000 th one is done
# 57114 th one is done
# 37991 th one is done
# 44519 th one is done
# 80153 th one is done
# 97962 th one is done
# 518012 th one is done
# 8041 th one is done
# 11130 th one is done
# 42235 th one is done
# 00959 th one is done
# 527000 th one is done
# L6A0B9 th one is done
# 9758700 th one is done
# 428 th one is done
# 009703096 th one is done
# 518066 th one is done
# 53362 th one is done
# 00921 th one is done
# SE16 2PD th one is done
# 266034 th one is done
# 59161 th one is done
# 9112 th one is done
# 10288 th one is done
# 0114 th one is done
# 90618 th one is done
# SW9 6EL th one is done
# 11600 th one is done
# 64712 th one is done
# 18863 th one is done
# 525134 th one is done
# 60234 th one is done
# 00685-9704 th one is done
# 8389 th one is done
# 74433 th one is done
# 006277804 th one is done
# V9A6G4 th one is done
# 00710 th one is done
# 11591 th one is done
# 35566 th one is done
# 269304 th one is done
# 29057 th one is done
# 518019 th one is done
# 518411 th one is done
# 314500 th one is done
# 2905735 th one is done
# 24425 th one is done
# 736868 th one is done
# 64005 th one is done
# 518002 th one is done
# N2Z1B1 th one is done
# 82796 th one is done
# 34132 th one is done
# 524300 th one is done
# 4528659 th one is done
# 40700 th one is done
# 37038 th one is done
# 94155 th one is done
# ct19 5rp th one is done
# 523660 th one is done
# 10500 th one is done
# 96921-3008 th one is done
# 58114 th one is done
# 57708 th one is done
# 00934 th one is done
# 96910 th one is done
# 4107 th one is done
# 63174 th one is done
# 20089 th one is done
# 85200 th one is done
# 2233 th one is done
# 00715 th one is done
# 07777 th one is done
# 424300 th one is done
# 361001 th one is done
# 95964 th one is done
# 35346 th one is done
# 00725 th one is done
# 550620 th one is done
# 111156 th one is done
# BN25 3HW th one is done
# 32717 th one is done
# 46009 th one is done
# 518191 th one is done
# 89174 th one is done
# 00987 th one is done
# lu15jg th one is done
# 223400 th one is done
# 11080 th one is done
# 054100 th one is done
# 8220011 th one is done
# 92826 th one is done
# 322005 th one is done
# 21000 th one is done
# Kerry th one is done
# H4L 4C5 th one is done
# 21268 th one is done
# 52022 th one is done
# 23600 th one is done
# 3088 th one is done
# 00003 th one is done
# 02100 th one is done
# 00952 th one is done
# 511475 th one is done
# 10052 th one is done
# 1510 th one is done
# 6800 th one is done
# ST1 2LN th one is done
# 51271 th one is done
# 741000 th one is done
# 90761 th one is done
# 36100 th one is done
# 80344 th one is done
# 00795-2171 th one is done
# 76775 th one is done
# 16320 th one is done
# 37000 th one is done
# 2151 th one is done
# 309511 th one is done
# 529700 th one is done
# 7527308 th one is done
# 510431 th one is done
# 050040 th one is done
# 6513108 th one is done
# M29 7PU th one is done
# 7525847 th one is done
# 44329 th one is done
# 200003 th one is done
# T9W 1L1 th one is done
# 59372 th one is done
# L4A0L9 th one is done
# 2770043 th one is done
# 3153 th one is done
# 00715-0443 th one is done
# 93854 th one is done
# 541007 th one is done
# nan th one is done
# 41536 th one is done
# 41032 th one is done
# 94246 th one is done
# 00623 th one is done
# 437100 th one is done
# 1334 KD th one is done
# 150001 th one is done
# 84797 th one is done
# 34514 th one is done
# 02929 th one is done
# 32987 th one is done
# 11476 th one is done
# 17305 th one is done
# 00725-3421 th one is done
# 30209 th one is done
# 900000 th one is done
# DE12 7AQ th one is done
# 19223 th one is done
# 84430 th one is done
# 22354 th one is done
# 03553 th one is done
# 01477 th one is done
# 3848442 th one is done
# 91447 th one is done
# 27630 th one is done
# 55701 th one is done
# 41353 th one is done
# NW1 9DR th one is done
# V5E 3J7 th one is done
# 00972 th one is done
# 12710 th one is done
# 70952 th one is done
# 341800 th one is done
# 21955 th one is done
# 90119 th one is done
# 08860 th one is done
# 66140 th one is done
# shenzhen th one is done
# 75299 th one is done
# 56346 th one is done
# 9322830 th one is done
# 11750 th one is done
# 39720 th one is done
# 40600 th one is done
# 00820 th one is done
# 22090 th one is done
# 159999 th one is done
# 41211 th one is done
# 40474 th one is done
# 95700 th one is done
# 290000 th one is done
# 11353 th one is done
# 56483 th one is done
# 92631 th one is done
# 61 th one is done
# 00908 th one is done
# 37008 th one is done
# 82250 th one is done
# 00701 th one is done
# 36501 th one is done
# 深圳市 th one is done
# 5010 th one is done
# 650041 th one is done
# 510802 th one is done
# 7880323 th one is done
# 561000 th one is done
# 527100 th one is done
# 46100 th one is done
# 34962 th one is done
# 74321 th one is done
# L1N0C7 th one is done
# X1A 3T4 th one is done
# 25000 th one is done
# h7x1y1 th one is done
# 474250 th one is done
# 210001 th one is done
# 1330055 th one is done
# 7552817 th one is done
# L8N 3X3 th one is done
# 750004 th one is done
# 20307 th one is done
# 1006-1000 th one is done
# 19920 th one is done
# 9941002 th one is done
# 85231 th one is done
# 27321 th one is done
# 98132 th one is done
# 52273 th one is done
# 523770 th one is done
# 90917 th one is done
# 27737 th one is done
# 55281 th one is done
# 66312 th one is done
# 21942 th one is done
# 55135 th one is done
# 52020 th one is done
# 520120 th one is done
# 232000 th one is done
# 598-0072 th one is done
# 97505 th one is done
# 00670-2906 th one is done
# 7548405 th one is done
# 52394 th one is done
# 52489 th one is done
# 57561 th one is done
# 94865 th one is done
# 31737 th one is done
# 00624-9658 th one is done
# 1201 th one is done
# 9375800 th one is done
# 73808 th one is done
# 2064 th one is done
# B64NE th one is done
# 6064 th one is done
# 87100 th one is done
# 29814 th one is done
# 00777 th one is done
# 00919-3385 th one is done
# 130113 th one is done
# 400050 th one is done
# 19867 th one is done
# 90909 th one is done
# 366300 th one is done
# 02147 th one is done
# 85313 th one is done
# 35510 th one is done
# UB3 4UZ th one is done
# 2235416 th one is done
# V3H 5B3 th one is done
# 524200 th one is done
# 23080 th one is done
# PR2 1DA th one is done
# 528300 th one is done
# 34634 th one is done
# t2s 1z3 th one is done
# 31422 th one is done
# 115334 th one is done
# 32928 th one is done
# 350015 th one is done
# 45-578 th one is done
# 3085000 th one is done
# LV 1046 th one is done
# 09364 th one is done
# 56790 th one is done
# 215007 th one is done
# 00745 th one is done
# CH633AP th one is done
# 412420 th one is done
# 80361 th one is done
# 00794-8606 th one is done
# 880000 th one is done
# 516211 th one is done
# 3122 th one is done
# 08814 th one is done
# 201508 th one is done
# V6V 2K9 th one is done
# 510990 th one is done
# 245199 th one is done
# 43602 th one is done
# 1709 th one is done
# 130000 th one is done
# 00976 th one is done
# 90763 th one is done
# 7742117 th one is done
# 012000 th one is done
# 516622 th one is done
# 63100 th one is done
# 395004 th one is done
# 85504 th one is done
# 46027 th one is done
# 19780 th one is done
# 315303 th one is done
# PE13 2GA th one is done
# 211100 th one is done
# 43262 th one is done
# 60230 th one is done
# 473135 th one is done
# 75774 th one is done
# 9634402 th one is done
# 34665 th one is done
# 211181 th one is done
# L3P 0B7 th one is done
# 49828 th one is done
# 161006 th one is done
# 37703 th one is done
# 00698-4122 th one is done
# 10900 th one is done
# 88710 th one is done
# 60255 th one is done
# 13530 th one is done
# WF3 2BJ th one is done
# 00677 th one is done
# 1040 th one is done
# 33384 th one is done
# N4S4P7 th one is done
# V6X1N3 th one is done
# 94911 th one is done
# 86360 th one is done
# 90907 th one is done
# 5337627 th one is done
# 2045 th one is done
# 88907 th one is done
# 52393 th one is done
# 32414 th one is done
# 264209 th one is done
# 009242224 th one is done
# 03800 th one is done
# 88904 th one is done
# 3977 th one is done
# 17709 th one is done
# 4540 th one is done
# 00602-9490 th one is done
# 97550 th one is done
# B0M 1X0 th one is done
# 302039 th one is done
# 90944 th one is done
# 53419 th one is done
# 5867063 th one is done
# 58171 th one is done
# 78862 th one is done
# 33452 th one is done
# 16810 th one is done
# 80890 th one is done
# 60239 th one is done
# 46185 th one is done
# 2075 th one is done
# 725 th one is done
# 98081 th one is done
# 33289 th one is done
# BS4 3NH th one is done
# 29700 th one is done
# eh11 3sx th one is done
# 47891 th one is done
# 266326 th one is done
# 69000 th one is done
# 0179 th one is done
# 25760 th one is done
# 221005 th one is done
# 42910 th one is done
# 53134 th one is done
# L6T4G1 th one is done
# 2222009 th one is done
# 00924-2224 th one is done
# 543100 th one is done
# 1080 th one is done
# 610058 th one is done
# 143922 th one is done
# 1106 th one is done
# 35100 th one is done
# 14703 th one is done
# 99254 th one is done
# 10139 th one is done
# 930000 th one is done
# 515141 th one is done
# 23717 th one is done
# 882877 th one is done
# 06800 th one is done
# 621052 th one is done
# SE10 8RF th one is done
# 55186 th one is done
# 6802108 th one is done
# 92985 th one is done
# 109451 th one is done
# 52511 th one is done
# 28979 th one is done
# 473002 th one is done
# 1079 th one is done
# 461 61 th one is done
# 02510 th one is done
# 19238 th one is done
# 9908525 th one is done
# 11070 th one is done
# 083003 th one is done
# CR76DS th one is done
# 1695500 th one is done
# 110111 th one is done
# 402760 th one is done
# 10292 th one is done
# L3R 5T5 th one is done
# 91215 th one is done
# NG122EL th one is done
# 37718 th one is done
# 350090 th one is done
# 78310 th one is done
# 200235 th one is done
# CP 77536 th one is done
# 49390 th one is done
# 133300 th one is done
# 523867 th one is done
# G5 9QJ th one is done
# 920000 th one is done
# M41 9NE th one is done
# L8L3J1 th one is done
# 23468 th one is done
# 20480 th one is done
# 98067 th one is done
# 314400 th one is done
# 87650 th one is done
# 23020 th one is done
# 91671 th one is done
# L4K 3P4 th one is done
# 2430 th one is done
# 龙华新区 th one is done
# 56100 th one is done
# 白云 th one is done
# 213023 th one is done
# 30613 th one is done
# 450101 th one is done
# 4946609 th one is done
# 030024 th one is done
# L4K 4E9 th one is done
# 1824 th one is done
# 3119 th one is done
# 43179 th one is done
# 51311 th one is done
# 47301 th one is done
# M5T 1T3 th one is done
# 11821 th one is done
# 3300009 th one is done
# V5M 1J7 th one is done
# 60650 th one is done
# 72230 th one is done
# 10572 th one is done
# M1 1EL th one is done
# 33515 th one is done
# 34550 th one is done
# 523800 th one is done
# 38410 th one is done
# N89DJ th one is done
# K1Z 6V5 th one is done
# 02105 th one is done
# L6A2Z9 th one is done
# 32870 th one is done
# 680005 th one is done
# 523857 th one is done
# 00687-8513 th one is done
# 220120 th one is done
# 76224 th one is done
# 2596CH th one is done
# 14-500 th one is done
# 57692 th one is done
# 519108 th one is done
# 125009 th one is done
# 63413 th one is done
# 643000 th one is done
# 474500 th one is done
# 529632 th one is done
# 5226048 th one is done
# 11785 th one is done
# 22130 th one is done
# 215005 th one is done
# M9V4J2 th one is done
# 028007 th one is done
# 11621 th one is done
# 2304931 th one is done
# 847-0022 th one is done
# 600000 th one is done
# 19775 th one is done
# 7561705 th one is done
# 84975 th one is done
# 42212 th one is done
# H4N 1M9 th one is done
# 8476809 th one is done
# M3C2E8 th one is done
# 91000 th one is done
# galil th one is done
# 305004 th one is done
# 40127 th one is done
# 13075 th one is done
# 3545000 th one is done
# 00717 th one is done
# 38307 th one is done
# 44526 th one is done
# 80600 th one is done
# 10854 th one is done
# 62211 th one is done
# 43265 th one is done
# 92680 th one is done
# 92640 th one is done
# 0310 th one is done
# 96833 th one is done
# 390122 th one is done
# 6107 th one is done
# 31242 th one is done
# 19000 th one is done
# 210046 th one is done
# 6772126 th one is done
# L3S th one is done
# 60300 th one is done
# 53252 th one is done
# 40275 th one is done
# T2A 6J1 th one is done
# 009123839 th one is done
# 92964 th one is done
# 40696 th one is done
# K2K 2L7 th one is done
# 0536 th one is done
# 518022 th one is done
# 43700 th one is done
# 4030000 th one is done
# 29961 th one is done
# 48769 th one is done
# J7T 2H2 th one is done
# 335000 th one is done
# 006782949 th one is done
# 90180 th one is done
# 416814 th one is done
# 81341 th one is done
# 37543 th one is done
# 25900 th one is done
# 45455 th one is done
# 111396 th one is done
# 89909 th one is done
# 30219 th one is done
# 94826 th one is done
# 31-612 th one is done
# 15400 th one is done
# 530007 th one is done
# 08531 th one is done
# 084 th one is done
# 215003 th one is done
# 77097 th one is done
# 78782 th one is done
# 36012 th one is done
# V0E 1C0 th one is done
# 2035 th one is done
# 4938732 th one is done
# 02168 th one is done
# 3842117 th one is done
# 90612 th one is done
# 523039 th one is done
# 516600 th one is done
# ...
# AZ1074 th one is done
# 20231-110 th one is done
# 35092 th one is done
# 90100 th one is done
# 90871 th one is done
# 35030 th one is done
# ct16 1rp th one is done
# 3315 KX th one is done
# 80064 th one is done
# 31-216 th one is done
# 74210190 th one is done
# N0R 1K0 th one is done
# 125008 th one is done
# 22780 th one is done
# 40860 th one is done
# 12867 th one is done
# 31121 th one is done
# 7000 th one is done
# 4052 th one is done
# V6S 2G8 th one is done
# L8N2X8 th one is done
# 44935 th one is done
# 30100 th one is done
# 01130 th one is done
# 02401 th one is done
# NW4 4BT th one is done
# 04202-021 th one is done
# 59706 th one is done
# 88505 th one is done
# 5882408 th one is done
# 11700 th one is done
# 77366 th one is done
# 09603-0007 th one is done
# 94700 th one is done
# 33457 th one is done
# 32849 th one is done
# 13177 th one is done
# 650-0022 th one is done
# 00961-6205 th one is done
# L6M 4V3 th one is done
# 65-012 th one is done
# 91076 th one is done
# 6510 th one is done
# 66232 th one is done
# 2419 th one is done
# M5C 3C5 th one is done
# 2023 th one is done
# 4355 th one is done
# 83102 th one is done
# L5T1P1 th one is done
# 36210 th one is done
# 00830-9525 th one is done
# 01327002 th one is done
# - th one is done
# 03523030 th one is done
# 2380042 th one is done
# 39621 th one is done
# 34199 th one is done
# 00936-1290 th one is done
# 1145 th one is done
# H7T 2X8 th one is done
# 29110 th one is done
# 37093 th one is done
# 77760 th one is done
# 39707 th one is done
# 41111 th one is done
# R6W 2Z3 th one is done
# 400022 th one is done
# 468-0026 th one is done
# 82148 th one is done
# t2e 2t7 th one is done
# 38409 th one is done
# V5B 0A9 th one is done
# NW1 9HZ th one is done
# 00 th one is done
# K0B 1L0 th one is done
# 53324 th one is done
# 91904 th one is done
# 71215281 th one is done
# 798-4131 th one is done
# V9T 3Z3 th one is done
# 4558 th one is done
# 22022 th one is done
# 00795-9545 th one is done
# 03324-060 th one is done
# 111675 th one is done
# 43562 th one is done
# 33005 th one is done
# 00777-9706 th one is done
# 093630001 th one is done
# 38056 th one is done
# v1E 2P9 th one is done
# 23402 th one is done
# SO14 0PB th one is done
# 00982-1921 th one is done
# 09321-1820 th one is done
# 38403 th one is done
# 31500 th one is done
# 275-0017 th one is done
# V5j2m7 th one is done
# 357920 th one is done
# m9n 2j6 th one is done
# 8656 th one is done
# 62507 th one is done
# 98598 th one is done
# 91060971 th one is done
# DV 07 th one is done
# 9000 th one is done
# 80796 th one is done
# 3491588 th one is done
# J7W 0H3 th one is done
# 64038 th one is done
# 00960-2386 th one is done
# 0060016 th one is done
# V1L 4J3 th one is done
# L1N4V4 th one is done
# 47180 th one is done
# 962750004 th one is done
# 426063 th one is done
# 42203 th one is done
# 06900 th one is done
# K8A 3Y1 th one is done
# n0n1r0 th one is done
# 3024 th one is done
# 40610 th one is done
# 37529 th one is done
# 54-066 th one is done
# 8580708 th one is done
# 11502 th one is done
# 22010 th one is done
# 2048 th one is done
# 00718-3018 th one is done
# 6330 th one is done
# 115 th one is done
# 18119 th one is done
# 6116101 th one is done
# 06000 th one is done
# EC3R 6HD th one is done
# 4802 th one is done
# 18880 th one is done
# 693004 th one is done
# V3A4E7 th one is done
# 229516 th one is done
# L6W 2G1 th one is done
# 38092 th one is done
# 228281 th one is done
# 50490 th one is done
# 53592 th one is done
# 018960 th one is done
# 05415-001 th one is done
# 00681-1042 th one is done
# 18536 th one is done
# 4217 th one is done
# R3M 0Z7 th one is done
# 577-0066 th one is done
# 96386-0186 th one is done
# 00949-5321 th one is done
# L9J 0B7 th one is done
# SS0 9HA th one is done
# K0K 2T0 th one is done
# 44722 th one is done
# 51522 th one is done
# 58485 th one is done
# v3w2r7 th one is done
# H3K 0A8 th one is done
# M5S2W8 th one is done
# 41463 th one is done
# 31458 th one is done
# 8240000 th one is done
# 01114 th one is done
# N7S2M3 th one is done
# M2J 3B5 th one is done
# 37007 th one is done
# 1690075 th one is done
# 71723 th one is done
# 2025 th one is done
# 6063 th one is done
# 687031 th one is done
# ZBR 4429 th one is done
# L2A 1H2 th one is done
# 1560053 th one is done
# 179104 th one is done
# 1456 th one is done
# 00623-9059 th one is done
# R2W 1W9 th one is done
# L1X2T6 th one is done
# 00468 th one is done
# 22754 th one is done
# 30390 th one is done
# 68426 th one is done
# 5519 th one is done
# M9C 1C0 th one is done
# 2130005 th one is done
# 91703 th one is done
# 39334 th one is done
# 8000-080 th one is done
# 868-0623 th one is done
# 114-0012 th one is done
# 81500 th one is done
# R2W1P3 th one is done
# 966729319 th one is done
# P0w1k0 th one is done
# v0r 2g0 th one is done
# 859-3243 th one is done
# 95022 th one is done
# L9Y 3T1 th one is done
# 1680065 th one is done
# 92600 th one is done
# 75003 th one is done
# T2V 4A3 th one is done
# 2680 th one is done
# 628001 th one is done
# 70316-000 th one is done
# 12322 th one is done
# 52382 th one is done
# S4S 3Y7 th one is done
# V4C 0B9 th one is done
# 00823-8539 th one is done
# 33505 th one is done
# j1k 2s7 th one is done
# 00627-0705 th one is done
# 91100 th one is done
# V9R6Z8 th one is done
# Hong Kong th one is done
# 32069 th one is done
# L4K5J2 th one is done
# 79632 th one is done
# 18226 th one is done
# 09363-0003 th one is done
# ML3 9XW th one is done
# 12109 th one is done
# 71756 th one is done
# 76080 th one is done
# 38540 th one is done
# 85393 th one is done
# 09603-0037 th one is done
# 00605-0798 th one is done
# 90164 th one is done
# 31230 th one is done
# 38813 th one is done
# V7B0B7 th one is done
# 21340 th one is done
# A0H 1E0 th one is done
# 00554 th one is done
# 05349 th one is done
# 08786 th one is done
# 2137 th one is done
# 220 th one is done
# 00729-1609 th one is done
# 00153 th one is done
# M6J 2A6 th one is done
# 2280 th one is done
# 23946 th one is done
# 10300 th one is done
# 90836 th one is done
# 116021 th one is done
# L2R 7C3 th one is done
# 6580016 th one is done
# 96799-1449 th one is done
# 550006 th one is done
# 01402000 th one is done
# 00-621 th one is done
# 5700 th one is done
# 23033 th one is done
# L7R 4A9 th one is done
# 03030 th one is done
# 19517 th one is done
# 154-0022 th one is done
# 39585 th one is done
# H3Y 2N1 th one is done
# 158-0094 th one is done
# 52764 th one is done
# 009719411 th one is done
# V1L1Y8 th one is done
# 00778-9101 th one is done
# 5400004 th one is done
# R1A 2M2 th one is done
# 20806 th one is done
# 00732-0447 th one is done
# 49205 th one is done
# 66666 th one is done
# 26001 th one is done
# 65957 th one is done
# 82330 th one is done
# 1350061 th one is done
# 00627-9426 th one is done
# 00940-0678 th one is done
# 1051 th one is done
# 78740 th one is done
# B1P 2N3 th one is done
# V1p 1g4 th one is done
# CO27PX th one is done
# T6W 2K6 th one is done
# 08500 th one is done
# V3R0J1 th one is done
# 00741-0276 th one is done
# 33366 th one is done
# 39050 th one is done
# 10660 th one is done
# 00739-1658 th one is done
# B4A 2Z5 th one is done
# 49049 th one is done
# 2390831 th one is done
# 151-0051 th one is done
# v4w 4a7 th one is done
# 3184 th one is done
# 31666 th one is done
# 2610 th one is done
# TH20150 th one is done
# 35791 th one is done
# 929-2125 th one is done
# 319-1304 th one is done
# 107392 th one is done
# 450450 th one is done
# 6924 th one is done
# 135-0031 th one is done
# 08237 th one is done
# 00688-9777 th one is done
# V6T 2G9 th one is done
# 97245 th one is done
# 00676-9708 th one is done
# 5704 LK th one is done
# 83180 th one is done
# M4V 2Y8 th one is done
# 46200 th one is done
# K1J 1J9 th one is done
# 413843 th one is done
# 45180 th one is done
# 3920 th one is done
# j7w4j5 th one is done
# 00682-6625 th one is done
# 34298 th one is done
# M1R 3Y3 th one is done
# 37124 th one is done
# 35590 th one is done
# 96251-0007 th one is done
# T4S 1S5 th one is done
# M4G 1G4 th one is done
# 102212 th one is done
# 96799-2452 th one is done
# 41131 th one is done
# 192131 th one is done
# J0Y2X0 th one is done
# 82600 th one is done
# V1W4C1 th one is done
# 36883 th one is done
# L4C 3G1 th one is done
# 09751-0010 th one is done
# 21190 th one is done
# 91700 th one is done
# 260-0021 th one is done
# h7l4a1 th one is done
# 28186 th one is done
# Lima -34 th one is done
# M6J1R3 th one is done
# 5683 th one is done
# 107370 th one is done
# 41118 th one is done
# 2012 th one is done
# 4215 th one is done
# 7630 th one is done
# 1495000 th one is done
# 14331 th one is done
# K0M 2B0 th one is done
# NG3 6EX th one is done
# 2480 th one is done
# L7A 1C2 th one is done
# 8630 th one is done
# 00729-4524 th one is done
# 46445 th one is done
# 32914 th one is done
# J2G 4T1 th one is done
# V1L 6M1 th one is done
# M5B2L4 th one is done
# 35857 th one is done
# E1 8PY th one is done
# 5829109 th one is done
# V2K 3V3 th one is done
# 6532 th one is done
# 01049 th one is done
# 8140 th one is done
# 40761 th one is done
# 6048804 th one is done
# 6550812 th one is done
# V6A1B2 th one is done
# 142301 th one is done
# M3C 1A6 th one is done
# 102-0094 th one is done
# 1672 th one is done
# 96950-1817 th one is done
# V9E 2C6 th one is done
# 194-0014 th one is done
# M2K 1E8 th one is done
# RH103ee th one is done
# 29.055-340 th one is done
# 96952-0425 th one is done
# 21510 th one is done
# 272-0031 th one is done
# 32-700 th one is done
# 42200 th one is done
# 00739-8963 th one is done
# T5R 5P1 th one is done
# 270-0021 th one is done
# T6K 3S0 th one is done
# 00716-2115 th one is done
# V3J 4E4 th one is done
# 71.630-265 th one is done
# 10442 th one is done
# 00726-7066 th one is done
# 00674-6354 th one is done
# 94400 th one is done
# 224-0015 th one is done
# 36690 th one is done
# 31718 th one is done
# 54219 th one is done
# 70608 th one is done
# 09603-0051 th one is done
# 4500 th one is done
# 00983-2101 th one is done
# M168LD th one is done
# 33115 th one is done
# 7340007 th one is done
# 30723 th one is done
# K0K 1H0 th one is done
# 00953-4846 th one is done
# 69007 th one is done
# 33089 th one is done
# 2340000 th one is done
# 35432 th one is done
# GL10 3NT th one is done
# 2775-277 th one is done
# 60182-026 th one is done
# 00612-5936 th one is done
# 40248 th one is done
# 2780 th one is done
# 3760023 th one is done
# 20304 th one is done
# 80493 th one is done
# 3170 th one is done
# UAE th one is done
# 4518 th one is done
# J1A 1R2 th one is done
# 80484 th one is done
# 32051 th one is done
# 200232 th one is done
# N0H2C3 th one is done
# 26067 th one is done
# 70604 th one is done
# 03069 th one is done
# T9V 1T5 th one is done
# N8R 2A6 th one is done
# 96251-0067 th one is done
# Lima 18 th one is done
# KY1-1103 th one is done
# 96990 th one is done
# 51 th one is done
# 32374 th one is done
# 40321 th one is done
# 06962 th one is done
# L7S 1P4 th one is done
# 7750067 th one is done
# 00933-3080 th one is done
# 81570 th one is done
# 07301 th one is done
# g9p4p8 th one is done
# V0R 2H0 th one is done
# H3J 2R9 th one is done
# 10245 th one is done
# N1E 5R1 th one is done
# 38360 th one is done
# 00738-3953 th one is done
# V7H 1C9 th one is done
# J7V 2K0 th one is done
# 37609 th one is done
# 7009 th one is done
# 31913 th one is done
# X5002AAY th one is done
# 90218 th one is done
# 09309-1233 th one is done
# 03020 th one is done
# 6436106 th one is done
# 96931-3142 th one is done
# 8953 th one is done
# 25227 th one is done
# 61494 th one is done
# 09603-0035 th one is done
# WK02 th one is done
# 1455 th one is done
# L3P 3J3 th one is done
# 04026001 th one is done
# 2264 th one is done
# 64565 th one is done
# 06780 th one is done
# 231-0862 th one is done
# 09603-0010 th one is done
# 603 th one is done
# 00650-0270 th one is done
# M4M 2P7 th one is done
# L6S4J1 th one is done
# 00725-3378 th one is done
# 999078 th one is done
# 11471 th one is done
# 96601-3600 th one is done
# 35039 th one is done
# 30654 th one is done
# 4610101 th one is done
# 0175 th one is done
# H2C1R2 th one is done
# l8e2g9 th one is done
# 86368 th one is done
# 10692 th one is done
# 116 42 th one is done
# 78848 th one is done
# G0M1J0 th one is done
# 0930 th one is done
# G43 1UA th one is done
# 25448 th one is done
# L5M 5Z6 th one is done
# 24294 th one is done
# 35527 th one is done
# V5P 1V3 th one is done
# 68912 th one is done
# 26701 th one is done
# 23553 th one is done
# 25730775 th one is done
# 00754-0793 th one is done
# L4G 7M5 th one is done
# 18941 th one is done
# N2L3G1 th one is done
# 10719 th one is done
# 562-0013 th one is done
# 57124 th one is done
# 00851-4910 th one is done
# 153-42 th one is done
# 109518 th one is done
# 23558 th one is done
# M9L1Z3 th one is done
# M5S 2H8 th one is done
# 34784 th one is done
# 39642 th one is done
# 00959-5819 th one is done
# 54953 th one is done
# V6Z 2M9 th one is done
# J1J 4H9 th one is done
# 6065 th one is done
# 00775-0147 th one is done
# 67918 th one is done
# 20332 th one is done
# 34227 th one is done
# 37634 th one is done
# 34225 th one is done
# 46092 th one is done
# 22105 th one is done
# 71930750 th one is done
# v3a8c3 th one is done
# 5703 th one is done
# 34619 th one is done
# 09309-1205 th one is done
# 39178 th one is done
# 78-100 th one is done
# 672-8051 th one is done
# t5n2h4 th one is done
# L5H 4J1 th one is done
# 13243 th one is done
# NW1 9SL th one is done
# 00984-9781 th one is done
# 270-1342 th one is done
# 1030 th one is done
# 00676-1405 th one is done
# 5890022 th one is done
# 203 th one is done
# 426000 th one is done
# 29489 th one is done
# 10082 th one is done
# T6L 3N6 th one is done
# 57011 th one is done
# 86522 th one is done
# L3Z 3C1 th one is done
# 127572 th one is done
# Lima 27 th one is done
# CP 07510 th one is done
# 94650 th one is done
# 30618 th one is done
# 2777 th one is done
# 4093 th one is done
# 31455 th one is done
# 96351-0046 th one is done
# 00918-2638 th one is done
# 38005 th one is done
# J0X 2W0 th one is done
# 38757 th one is done
# 00804-1260 th one is done
# 27121 th one is done
# 62826 th one is done
# 11523 th one is done
# 02619 th one is done
# V4T 2C9 th one is done
# 05080-010 th one is done
# 165-0034 th one is done
# T5x 5r7 th one is done
# 00667-3161 th one is done
# V8L 5L5 th one is done
# V5G4W6 th one is done
# 326-0067 th one is done
# 96921-6295 th one is done
# 1250 th one is done
# m1m2z9 th one is done
# 0614 th one is done
# G0A 4V0 th one is done
# 4551 th one is done
# 69710 th one is done
# M4Y1R5 th one is done
# 92100 th one is done
# L6Y6B1 th one is done
# 300 th one is done
# 3118 th one is done
# V6V1W1 th one is done
# 36223 th one is done
# 56234 th one is done
# 22584 th one is done
# 00767-9776 th one is done
# N5V 2T4 th one is done
# 170-304 th one is done
# 46665 th one is done
# V0A 1H0 th one is done
# 35701 th one is done
# V0E1B4 th one is done
# 43650 th one is done
# K0C 1Z0 th one is done
# 00983-1761 th one is done
# 7621 th one is done
# 82110 th one is done
# L0K 1E0 th one is done
# 141612 th one is done
# 00928-3353 th one is done
# 8480 th one is done
# 36989 th one is done
# V6G 1M6 th one is done
# 28003 th one is done
# 53730 th one is done
# 94740 th one is done
# 109004 th one is done
# 7901 th one is done
# L6M 0S4 th one is done
# 01210 th one is done
# 2481 th one is done
# OX284BN th one is done
# 03306 th one is done
# 6141 th one is done
# 005-0005 th one is done
# 38823 th one is done
# 962750005 th one is done
# C0B1M0 th one is done
# 8808 th one is done
# 37980 th one is done
# 28860 th one is done
# 41218 th one is done
# 2830 th one is done
# 7946 th one is done
# J5T 3C6 th one is done
# G2N 1M9 th one is done
# 02244 th one is done
# 3070000 th one is done
# 5937 th one is done
# 6596 AG th one is done
# 03239 th one is done
# V2R 0G3 th one is done
# 09603-0024 th one is done
# 6436521 th one is done
# 43304 th one is done
# 00676-9718 th one is done
# 20642 th one is done
# v5h 2t9 th one is done
# 9420 th one is done
# 3138 th one is done
# 39123 th one is done
# 00917-3632 th one is done
# 177-0033 th one is done
# 09603-0005 th one is done
# J5J 1J7 th one is done
# 12892 th one is done
# 75736 th one is done
# 00731-9431 th one is done
# x th one is done
# Po Box 80666 th one is done
# 3844 th one is done
# 24755 th one is done
# 39036 th one is done
# k0a3h0 th one is done
# 21243 th one is done
# 92634 th one is done
# 7750000 th one is done
# 10200 th one is done
# 5495 th one is done
# H9R 4G5 th one is done
# 64287 th one is done
# 28046 th one is done
# 96931-8781 th one is done
# 34077 th one is done
# 63360 th one is done
# V6K 2S2 th one is done
# 1920371 th one is done
# 21344 th one is done
# 66254 th one is done
# 25240 th one is done
# R3P 1R1 th one is done
# T2Y 3C7 th one is done
# 7670 th one is done
# 63196 th one is done
# 6078177 th one is done
# 37102 th one is done
# 95900 th one is done
# L4J 7K4 th one is done
# 37084 th one is done
# 00978-0107 th one is done
# T4b 1k3 th one is done
# 00622-1942 th one is done
# 007729633 th one is done
# M5V 1B2 th one is done

# %%
missing_values = pd.read_csv('missing.csv')

# %%
missing_values
# Out:
#       Unnamed: 0 missing_zip state_name  latitude  longtitude
# 0              0       00627         PR   18.4838    -66.8449
# 1              1      518000        NaN       NaN         NaN
# 2              2      510420        NaN       NaN         NaN
# 3              3      610000         RU   58.5969     49.6583
# 4              4      510655        NaN       NaN         NaN
# ...          ...         ...        ...       ...         ...
# 4213        4213  00978-0107        NaN       NaN         NaN
# 4214        4214     T4b 1k3         CA   51.3082   -114.0398
# 4215        4215  00622-1942        NaN       NaN         NaN
# 4216        4216   007729633        NaN       NaN         NaN
# 4217        4217     M5V 1B2         CA   43.6404    -79.3995
#
# [4218 rows x 5 columns]

# %%
df = df.loc[df['duration'] >= 0 ]

# %%
df
# Out:
#          b2c_c2c  seller_id  ...  delivery_date2 duration
# 0            B2C      25454  ...      2019-03-29        3
# 1            C2C    6727381  ...      2018-06-05        3
# 2            B2C      18507  ...      2019-01-10        3
# 3            B2C       4677  ...      2018-12-21        4
# 4            B2C       4677  ...      2018-07-30        3
# ...          ...        ...  ...             ...      ...
# 14999995     B2C      80139  ...      2018-05-07        3
# 14999996     C2C     452486  ...      2018-05-08        6
# 14999997     B2C      43307  ...      2018-06-11        5
# 14999998     B2C      24235  ...      2018-12-20        3
# 14999999     C2C     535916  ...      2018-05-07        4
#
# [14985134 rows x 43 columns]

# %%
df_subset = df.loc[:, ['buyer_state', 'item_state', 'duration']]
df1 = df_subset.groupby(['buyer_state', 'item_state']).duration.agg(['max', 'min','mean', q25, 'median', q75])

# %%
rename

# %%
df = df.join(df1, on=['buyer_state', 'item_state'], how = 'left')
quiz = quiz.join(df1, on = ['buyer_state', 'item_state'], how = 'left')

# %%
#not necessary do not run this cell
df_subset = df.loc[:, ['buyer_zip', 'item_zip', 'duration']]
df1 = df_subset.groupby(['buyer_zip', 'item_zip']).duration.agg(['max', 'min','mean', q25, 'median', q75])
df = df.join(df1, on=['buyer_zip', 'item_zip'], how = 'left')
quiz = quiz.join(df1, on = ['buyer_zip', 'item_zip'], how = 'left')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-c11a0f377df7> in <module>()
#       1 df_subset = df.loc[:, ['buyer_zip', 'item_zip', 'duration']]
# ----> 2 df1 = df_subset.groupby(['buyer_zip', 'item_zip']).duration.agg(['max', 'min','mean', q25, 'median', q75])
#       3 df = df.join(df1, on=['buyer_zip', 'item_zip'], how = 'left')
#       4 quiz = quiz.join(df1, on = ['buyer_zip', 'item_zip'], how = 'left')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     244             # but not the class list / tuple itself.
#     245             func = maybe_mangle_lambdas(func)
# --> 246             ret = self._aggregate_multiple_funcs(func)
#     247             if relabeling:
#     248                 ret.columns = columns
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg)
#     317                 obj._reset_cache()
#     318                 obj._selection = name
# --> 319             results[base.OutputKey(label=name, position=idx)] = obj.aggregate(func)
#     320
#     321         if any(isinstance(x, DataFrame) for x in results.values()):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     254             if self.grouper.nkeys > 1:
#     255                 return self._python_agg_general(
# --> 256                     func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     257                 )
#     258
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, engine, engine_kwargs, *args, **kwargs)
#    1083                 try:
#    1084                     # if this function is invalid for this dtype, we will ignore it.
# -> 1085                     result, counts = self.grouper.agg_series(obj, f)
#    1086                 except TypeError:
#    1087                     continue
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, engine, engine_kwargs, *args, **kwargs)
#     649
#     650         try:
# --> 651             return self._aggregate_series_fast(obj, func)
#     652         except ValueError as err:
#     653             if "Function does not reduce" in str(err):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     674         group_index = algorithms.take_nd(group_index, indexer, allow_fill=False)
#     675         grouper = libreduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 676         result, counts = grouper.get_result()
#     677         return result, counts
#     678
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1060         func = self._is_builtin_func(func)
#    1061         if engine != "numba":
# -> 1062             f = lambda x: func(x, *args, **kwargs)
#    1063
#    1064         # iterate through "columns" ex exclusions to populate output dict
#
# <ipython-input-4-d821d9bf426f> in q25(x)
#      33 # 25% quantile
#      34 def q25(x):
# ---> 35     return x.quantile(0.25)
#      36 # 75th Percentile
#      37 def q75(x):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    2272         df = self.to_frame()
#    2273
# -> 2274         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2275         if result.ndim == 2:
#    2276             result = result.iloc[:, 0]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation)
#    9062
#    9063         result = data._mgr.quantile(
# -> 9064             qs=q, axis=1, interpolation=interpolation, transposed=is_transposed
#    9065         )
#    9066
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in quantile(self, axis, consolidate, transposed, interpolation, qs, numeric_only)
#     464         axes, blocks = [], []
#     465         for b in self.blocks:
# --> 466             block = b.quantile(axis=axis, qs=qs, interpolation=interpolation)
#     467
#     468             axe = get_axe(b, qs, axes=self.axes)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in quantile(self, qs, interpolation, axis)
#    1455                 mask=mask,
#    1456                 ndim=values.ndim,
# -> 1457                 interpolation=interpolation,
#    1458             )
#    1459
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanpercentile(values, q, axis, na_value, mask, ndim, interpolation)
#    1556             return result
#    1557     else:
# -> 1558         return np.percentile(values, q, axis=axis, interpolation=interpolation)
#    1559
#    1560
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3731         raise ValueError("Percentiles must be in the range [0, 100]")
#    3732     return _quantile_unchecked(
# -> 3733         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3734
#    3735
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3851     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3852                     overwrite_input=overwrite_input,
# -> 3853                     interpolation=interpolation)
#    3854     if keepdims:
#    3855         return r.reshape(q.shape + k)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3966
#    3967         x1 = take(ap, indices_below, axis=axis) * weights_below
# -> 3968         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3969
#    3970         # ensure axis with q-th is first
#
# <__array_function__ internals> in take(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in take(a, indices, axis, out, mode)
#     189            [5, 7]])
#     190     """
# --> 191     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     192
#     193
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %% [markdown]
# #Train the XGboost

# %%
import pandas as pd
import numpy as np
from numpy import random
random.seed(1998)
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ebay
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ebay

# %%
##If needed to load in data, here is the way
df = pd.read_hdf('Xgboost_trainingdata.h5')
quiz = pd.read_hdf('Xgboost_quiz.h5')

# %%
df.columns
# Out:
# Index(['Is_within_US', 'is_payment_weekend', 'is_scan_weeknd', 'item_lat',
#        'item_long', 'buyer_lat', 'buyer_long', 'B2B', 'seller_id',
#        'declared_handling_days', 'shipment_method_id', 'shipping_fee',
#        'carrier_min_estimate', 'carrier_max_estimate', 'category_id',
#        'item_price', 'quantity', 'weight', 'weight_units',
#        'time_zone_difference', 'seller_hour', 'larger_than_2pm', 'pay_month',
#        'pay_year', 'scan_month', 'payment_hour', 'scan_hour', 'Weekday_scan',
#        'Weekday_pay', 'payment_quarter', 'min_delivery', 'max_delivery',
#        'distance', 'max', 'min', 'mean', 'q25', 'median', 'q75',
#        'size_ordinal', 'duration'],
#       dtype='object')

# %%
X_quiz = quiz[['Is_within_US','is_payment_weekend', 'is_scan_weeknd','item_lat', 'item_long', 'buyer_lat', 'buyer_long','B2B','seller_id' ,'declared_handling_days','shipment_method_id','shipping_fee','carrier_min_estimate','carrier_max_estimate','category_id','item_price','quantity','weight','weight_units','time_zone_difference','seller_hour','larger_than_2pm','pay_month','pay_year','scan_month','payment_hour','scan_hour','Weekday_scan','Weekday_pay','payment_quarter','min_delivery','max_delivery','distance','max','min'	,'mean'	,'q25',	'median','q75','size_ordinal']]

# %%
X = df[['Is_within_US','is_payment_weekend', 'is_scan_weeknd','item_lat', 'item_long', 'buyer_lat', 'buyer_long','B2B','seller_id' ,'declared_handling_days','shipment_method_id','shipping_fee','carrier_min_estimate','carrier_max_estimate','category_id','item_price','quantity','weight','weight_units','time_zone_difference','seller_hour','larger_than_2pm','pay_month','pay_year','scan_month','payment_hour','scan_hour','Weekday_scan','Weekday_pay','payment_quarter','min_delivery','max_delivery','distance','max','min'	,'mean'	,'q25',	'median','q75','size_ordinal']]
y = df[['duration']]

# %%
#X_quiz.to_hdf('Xgboost_quiz.h5', key = 'X_quiz', mode = 'w')

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.5, learning_rate = 0.1,
                max_depth = 7, alpha = 10, n_estimators = 100)

# %%
xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# [22:24:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:24:18] WARNING: /workspace/src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# RMSE: 1.419268

# %%
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 1.425460

# %%
def loss(preds, y_test):
  new_y = y_test.values.flatten()
  result = new_y - preds
  late = 0
  early = 0
  for i in range(len(result)):
    if result[i] > 0:
      late = late + result[i]
    elif result[i] < 0:
      early = early + abs(result[i])
  
  total = (early*0.4 + late*0.6)/len(result)
  return total

# %%
print("LOSS: %f" % (loss(preds, y_test)))
# Out:
# LOSS: 0.420468

# %%
def rounding(arr, value):
  new = np.zeros(np.shape(arr))
  for i in range(len(arr)):
    if arr[i] - arr[i]//1 <= value:
      new[i] = arr[i]//1
    else:
      new[i] = arr[i]//1 + 1
  return new

# %%
#see what will be the optimal rounding rule
grid = [0.62, 0.63, 0.65,0.66]
def find_optimal_rounding(preds, y_test):
  for i in range(len(grid)):
    new_pred = rounding(preds, grid[i])
    print("LOSS: %f" % (loss(new_pred, y_test)))

# %%
find_optimal_rounding(preds, y_test)
# Out:
# LOSS: 0.401418
# LOSS: 0.401390
# LOSS: 0.401505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-4eaeea4811a8> in <module>()
# ----> 1 find_optimal_rounding(preds, y_test)
#
# <ipython-input-38-076b3a31697b> in find_optimal_rounding(preds, y_test)
#       3 def find_optimal_rounding(preds, y_test):
#       4   for i in range(len(grid)):
# ----> 5     new_pred = rounding(preds, grid[i])
#       6     print("LOSS: %f" % (loss(new_pred, y_test)))
#
# <ipython-input-33-88d4b16fd9bd> in rounding(arr, value)
#       2   new = np.zeros(np.shape(arr))
#       3   for i in range(len(arr)):
# ----> 4     if arr[i] - arr[i]//1 <= value:
#       5       new[i] = arr[i]//1
#       6     else:
#
# KeyboardInterrupt:

# %%
#this seems to be not working

def loss(preds, dtrain):
    ''' Customized loss function designing to punish earlier delivery date more than later delivery date'''
    y = dtrain.get_label()
    early = (sum(abs(preds[preds < y] - y[preds < y])))*0.4
    late = (sum(abs(preds[preds > y] - y[preds < y])))*0.6
    loss = (early + late)/len(y)
    return 'loss', loss

# %%
'''params = {"objective":"reg:linear",'colsample_bytree': 0.5,'learning_rate': 0.1,
                'max_depth':7, 'alpha': 10, 'n_estimators': 100, 'num_boost_round':100 } # 'disable_default_eval_metric': 1

xg_reg = xgb.train(params=params, dtrain=data_dmatrix)'''
'''cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=5,
                , early_stopping_rounds=10,metrics="rmse"
          as_pandas=True, seed=123)'''
# Out:
# [01:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:24:01] WARNING: /workspace/src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# 'cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=5,\n                , early_stopping_rounds=10,metrics="rmse"\n          as_pandas=True, seed=123)'

# %%
preds_quiz = xg_reg.predict(xgb.DMatrix(X_quiz))

# %%
#use this if did not use train
preds_quiz = xg_reg.predict(X_quiz)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-68e490bafb48> in <module>()
# ----> 1 preds_quiz = xg_reg.predict(X_quiz)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1282
#    1283         if validate_features:
# -> 1284             self._validate_features(data)
#    1285
#    1286         length = c_bst_ulong()
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in _validate_features(self, data)
#    1673         else:
#    1674             # Booster can't accept data with different feature names
# -> 1675             if self.feature_names != data.feature_names:
#    1676                 dat_missing = set(self.feature_names) - set(data.feature_names)
#    1677                 my_missing = set(data.feature_names) - set(self.feature_names)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names'

# %%
preds_round = preds_quiz.round()
quiz['duration'] = pd.DataFrame({'col': preds_round.tolist()})
quiz['delivery_date'] = quiz['acceptance_scan_time2'] + pd.to_timedelta(quiz['duration'], unit='D')
quiz['delivery_date'] = quiz['delivery_date'].astype(str)
submit = quiz[['record_number','delivery_date']]
submit.to_csv("submit_1118_depth7_max10_n70_.tsv.gz", 
           index=False, sep='\t', header = False, compression = 'gzip')

# %%
def rounding_rule(arr):
  new = np.zeros(np.shape(arr))
  for i in range(len(arr)):
    if arr[i] - arr[i]//1 <= 0.91:
      new[i] = arr[i]//1
    else:
      new[i] = arr[i]//1 + 1
  return new

# %%
quiz = pd.read_csv('eBay_ML_Challenge_Dataset_2021_quiz.tsv', sep='\t')

# %%
quiz['acceptance_scan_time2'] = quiz['acceptance_scan_timestamp'].apply(lambda x: x[:10])
quiz['acceptance_scan_time2'] = pd.to_datetime(quiz['acceptance_scan_time2'])

# %%
preds_new = rounding_rule(preds_quiz)
quiz['duration_91'] = pd.DataFrame({'col': preds_new.tolist()})
quiz['delivery_date_91'] = quiz['acceptance_scan_time2'] + pd.to_timedelta(quiz['duration_91'], unit='D')
submit_new = quiz[['record_number','delivery_date_91']]
submit_new.to_csv("submit_0106_depth7_max10_n100_cosample05_round91_trainwholedataset.tsv.gz", 
           index=False, sep='\t', header = False, compression = 'gzip')

# %%
#the minimum loss
#is when you only merge on data ['buyer_state', 'item_state']
#max_depth = 7, alpha = 10, number_estimators = 100, rounding = 83

# %%
import numpy as np
arr = np.zeros((2,3))

# %%
arr[1,2] = 8
arr[1,1] = -5
arr[0,2] = 9

# %%
np.abs(arr[arr>0])
# Out:
# array([9., 8.])
